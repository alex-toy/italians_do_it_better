# %%
import pandas as pd

# %%
df = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='VOLUME - HMSM')

# %%
data = df.iloc[4:]
data.columns = ['LIBELLE_PRODUIT_NIELSEN', 'LIBELLE_PRODUIT_OPTIMISE', 'MARQUE',
       'INGREDIENTS_PRINCIPAUX', 'GRAMMAGE', 'BIO_NON_BIO', 'CODE_EAN',
       'VOL_CAM_AN-1', 'VOL_DERNIER_CAM', 'EVOL', 'EVOL_PERC']

# %%
#GRAMMAGE missing values
mean_GRAMMAGE = data['GRAMMAGE'].mean()
data.loc[:,'GRAMMAGE'].fillna(mean_GRAMMAGE, inplace=True)

# %%
data
# Out:
#                                 LIBELLE_PRODUIT_NIELSEN  \
# 4     POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# 5     FECULENTS POT PANZANI SA PANZANI BOLO CLASSIQU...
# 6     POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# 7     FECULENTS POT PANZANI SA PANZANI BOLO CLASSIQU...
# 8     POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# ...                                                 ...
# 1272  POT ZAPETTI ZAPETTI BUITONI LEGUMES PF PROVENC...
# 1273  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
# 1274  POT ZAPETTI ZAPETTI BUITONI LEGUMES PF PROVENC...
# 1275  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
# 1276  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
#
#                            LIBELLE_PRODUIT_OPTIMISE                 MARQUE  \
# 4                           PANZANI PROVENCALE 425G                PANZANI
# 5                 PANZANI BOLOGNAISE CLASSIQUE 425G                PANZANI
# ...

# %%
df_panzani = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 PANZANI')

# %%
df_barilla = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 BARILLA')

# %%
df_sacla = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 SACLA')

# %%
df_sacla
# Out:
#                              LIBELLE PRODUIT NIELSEN  \
# 0  SAUCES POUR FECULENTS POT SACLA LEGUMES PF ARR...
# 1  SAUCES POUR FECULENTS POT SACLA LEGUMES PF CAV...
# 2  SAUCES POUR FECULENTS POT SACLA LEGUMES PF POI...
# 3  SAUCES POUR FECULENTS POT SACLA LEGUMES PF TOM...
# 4  SAUCES POUR FECULENTS POT SACLA LEGUMES MF TOM...
# 5  SAUCES POUR FECULENTS POT SACLA PESTO PF PESTO...
# 6  SAUCES POUR FECULENTS POT SACLA LEGUMES MF ARR...
# 7  SAUCES POUR FECULENTS POT SACLA PESTO PF PESTO...
# 8  SAUCES POUR FECULENTS POT SACLA PESTO PF PESTO...
# 9  SAUCES POUR FECULENTS POT SACLA BIO PF GENOVES...
#
#   LIBELLE PRODUIT OPTIMISE (MARQUE - VARIETE - POIDS) MARQUE  \
# 0                              SACLA ARRABBIATA 190G   SACLA
# 1                SACLA CAVIAR DE TOMATE A L'AIL 190G   SACLA
# 2              SACLA TRIO DE POIVONS AUBERGINES 190G   SACLA
# 3                          SACLA OLIVES TOMATES 190G   SACLA
# 4     SACLA TOMATES CERISES ENTIERES ET BASILIC 345G   SACLA
# ...
