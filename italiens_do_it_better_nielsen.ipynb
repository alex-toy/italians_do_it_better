# %%
import pandas as pd

# %%
#df = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='VOLUME - HMSM')
data = pd.read_csv('nielsen.csv')

# %%
#data = df.iloc[4:]
#data.columns = ['LIBELLE_PRODUIT_NIELSEN', 'LIBELLE_PRODUIT_OPTIMISE', 'MARQUE', 'INGREDIENTS_PRINCIPAUX', 'GRAMMAGE', 'BIO_NON_BIO', 'CODE_EAN', 'VOL_CAM_AN-1', 'VOL_DERNIER_CAM', 'EVOL', 'EVOL_PERC']

# %%
#GRAMMAGE missing values
#mean_GRAMMAGE = data['GRAMMAGE'].mean()
#data.loc[:,'GRAMMAGE_FILLED'] = data[['GRAMMAGE']].copy()
#data.loc[:,'GRAMMAGE_FILLED'].fillna(mean_GRAMMAGE, inplace=True)

# %%
#EVOL_PERC : there are missing values in the last column

# %%
data
# Out:
#       Unnamed: 0                            LIBELLE_PRODUIT_NIELSEN  \
# 0              0  POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# 1              1  FECULENTS POT PANZANI SA PANZANI BOLO CLASSIQU...
# 2              2  POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# 3              3  FECULENTS POT PANZANI SA PANZANI BOLO CLASSIQU...
# 4              4  POUR FECULENTS POT PANZANI SA PANZANI LEGUMES ...
# ...          ...                                                ...
# 1268        1268  POT ZAPETTI ZAPETTI BUITONI LEGUMES PF PROVENC...
# 1269        1269  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
# 1270        1270  POT ZAPETTI ZAPETTI BUITONI LEGUMES PF PROVENC...
# 1271        1271  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
# 1272        1272  FECULENTS POT ZAPETTI ZAPETTI BUITONI LEGUMES ...
#
#                            LIBELLE_PRODUIT_OPTIMISE                 MARQUE  \
# ...

# %%
df_panzani = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 PANZANI')

# %%
df_barilla = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 BARILLA')

# %%
df_sacla = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 SACLA')

# %%
df_florelli = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 FLORELLI')

# %%
df_jardin_bio = pd.read_excel(open(r'/Users/alexei/docs/formations/3WA/PP/nielsen.xlsx', 'rb'), sheet_name='TOP 10 JARDIN BIO')
