# %%
from pymongo import MongoClient
import pandas as pd
client = MongoClient()
db = client.openfoodfacts
collection = db.products

import sys
sys.path.append('../')
from func import *

# %%
proj = {
    'product_name_fr' : 1, 
    'ingredients' : 1,
    '_id' : 1,
}


match = {
    
    'ingredients' : { 
        "$elemMatch" : { 
            "text" : { '$regex' : "tomate*", '$options' : "i" },
        } 
    },
    
    "product_name_fr" : { '$regex' : "sauce*", '$options' : "i" }
    
}


c_f = collection.aggregate([
    { '$match' : match } ,
    { '$project' : proj },
])

ingredients = pd.DataFrame(list(c_f))

# %%
ingredients['ingredients'][100]
# Out:
# [{'id': 'en:crushed-tomato',
#   'text': 'Concentré de tomate',
#   'vegetarian': 'yes',
#   'vegan': 'yes',
#   'percent_max': 100,
#   'rank': 1,
#   'percent_min': 6.666666666666667},
#  {'percent_min': 0,
#   'vegetarian': 'yes',
#   'percent_max': 50,
#   'vegan': 'yes',
#   'rank': 2,
#   'id': 'en:vinegar',
#   'text': 'vinaigre'},
#  {'percent_min': 0,
#   'vegetarian': 'yes',
#   'rank': 3,
#   'percent_max': 33.333333333333336,
#   'vegan': 'yes',
#   'id': 'en:corn-syrup',
#   'text': 'sirop de mais'},
#  {'percent_max': 25,
#   'rank': 4,
#   'vegan': 'yes',
#   'vegetarian': 'yes',
#   'percent_min': 0,
#   'text': 'sucre brun',
#   'id': 'en:caramelised-sugar'},
#  {'percent_min': 0,
#   'vegetarian': 'yes',
#   'vegan': 'yes',
#   'rank': 5,
#   'percent_max': 20,
#   'id': 'en:sugar',
#   'text': 'sucre'},
#  {'text': 'épices',
#   'id': 'en:spice',
#   'percent_min': 0,
#   'percent_max': 16.666666666666668,
#   'vegan': 'yes',
#   'rank': 6,
#   'vegetarian': 'yes'},
#  {'percent_min': 0,
#   'vegetarian': 'yes',
#   'rank': 7,
#   'percent_max': 14.285714285714286,
#   'vegan': 'yes',
#   'id': 'en:salt',
#   'text': 'sel'},
#  {'percent_min': 0,
#   'vegetarian': 'yes',
#   'vegan': 'yes',
#   'percent_max': 12.5,
#   'rank': 8,
#   'id': 'en:molasses',
#   'text': 'mélasse'},
#  {'percent_min': 0,
#   'ingredients': [{'id': 'en:vinegar',
#     'text': 'vinaigre',
#     'percent_max': 11.11111111111111,
#     'percent_min': 0},
#    {'id': 'en:corn-syrup',
#     'text': 'sirop de maïs',
#     'percent_min': 0,
#     'percent_max': 5.555555555555555},
#    {'percent_min': 0,
#     'percent_max': 3.7037037037037037,
#     'id': 'en:water',
#     'text': 'eau'},
#    {'text': 'couleur caramel',
#     'id': 'fr:couleur caramel',
#     'percent_min': 0,
#     'percent_max': 2.7777777777777777},
#    {'text': '_anchois_',
#     'id': 'en:anchovy',
#     'processing': 'en:pureed',
#     'percent_max': 2.2222222222222223,
#     'percent_min': 0},
#    {'id': 'en:tamarind',
#     'text': 'tamarin',
#     'percent_max': 1.8518518518518519,
#     'percent_min': 0}],
#   'rank': 9,
#   'percent_max': 11.11111111111111,
#   'id': 'fr:Worcestershire',
#   'text': 'Worcestershire',
#   'has_sub_ingredients': 'yes'},
#  {'id': 'en:lemon-juice',
#   'text': 'jus de citron',
#   'percent_min': 0,
#   'vegetarian': 'yes',
#   'vegan': 'yes',
#   'rank': 10,
#   'percent_max': 10},
#  {'id': 'en:onion',
#   'text': 'oignon',
#   'percent_min': 0,
#   'vegetarian': 'yes',
#   'percent_max': 9.090909090909092,
#   'rank': 11,
#   'vegan': 'yes'},
#  {'percent_min': 0,
#   'percent_max': 8.333333333333334,
#   'rank': 12,
#   'text': 'ai!',
#   'id': 'fr:ai!'},
#  {'text': 'poivron',
#   'id': 'en:bell-pepper',
#   'vegan': 'yes',
#   'rank': 13,
#   'percent_max': 7.6923076923076925,
#   'vegetarian': 'yes',
#   'percent_min': 0},
#  {'text': 'arôme naturel',
#   'id': 'en:natural-flavouring',
#   'percent_min': 0,
#   'vegan': 'maybe',
#   'percent_max': 7.142857142857143,
#   'rank': 14,
#   'vegetarian': 'maybe'},
#  {'rank': 15,
#   'percent_max': 6.666666666666667,
#   'percent_min': 0,
#   'text': 'whiskey Jack Daniels',
#   'id': 'fr:whiskey Jack Daniels'},
#  {'vegetarian': 'yes',
#   'percent_max': 11.11111111111111,
#   'vegan': 'yes',
#   'percent_min': 0,
#   'id': 'en:vinegar',
#   'text': 'vinaigre'},
#  {'text': 'sirop de maïs',
#   'id': 'en:corn-syrup',
#   'percent_min': 0,
#   'vegan': 'yes',
#   'percent_max': 5.555555555555555,
#   'vegetarian': 'yes'},
#  {'id': 'en:water',
#   'text': 'eau',
#   'percent_min': 0,
#   'vegetarian': 'yes',
#   'vegan': 'yes',
#   'percent_max': 3.7037037037037037},
#  {'percent_min': 0,
#   'percent_max': 2.7777777777777777,
#   'text': 'couleur caramel',
#   'id': 'fr:couleur caramel'},
#  {'vegetarian': 'no',
#   'percent_max': 2.2222222222222223,
#   'vegan': 'no',
#   'percent_min': 0,
#   'id': 'en:anchovy',
#   'text': '_anchois_',
#   'processing': 'en:pureed'},
#  {'percent_max': 1.8518518518518519,
#   'percent_min': 0,
#   'text': 'tamarin',
#   'id': 'en:tamarind'}]

# %%
_id = []
denomination = []
ing = []
has_sub_ingredients = []
sub_ingredients = []
text = []
percent_min = []
percent_max = []
percent = []
rank = []
product_name_fr = []

for i in range(len(ingredients['ingredients'])) :
    for dict_ in ingredients['ingredients'][i] : 
        
        product_name_fr.append(ingredients['product_name_fr'][i])
        _id.append(ingredients['_id'][i])
        
        if 'id' in dict_.keys() :
            denomination.append(dict_['id'])
        else :
            id_.append(None)
        if 'ingredients' in dict_.keys() :
            ing.append(dict_['ingredients'])
        else :
            ing.append(None)
        if 'has_sub_ingredients' in dict_.keys() :
            has_sub_ingredients.append(dict_['has_sub_ingredients'])
        else :
            has_sub_ingredients.append(None)
        if 'ingredients' in dict_.keys() :
            sub_ingredients.append(dict_['ingredients'])
        else :
            sub_ingredients.append(None)
        if 'text' in dict_.keys() :
            text.append(dict_['text'])
        else :
            text.append(None)
        if 'percent_min' in dict_.keys() :
            percent_min.append(dict_['percent_min'])
        else :
            percent_min.append(None)
        if 'percent_max' in dict_.keys() :
            percent_max.append(dict_['percent_max'])
        else :
            percent_max.append(None)
        if 'percent' in dict_.keys() :
            percent.append(dict_['percent'])
        else :
            percent.append(None)
        if 'rank' in dict_.keys() :
            rank.append(dict_['rank'])
        else :
            rank.append(None)

# %%
df_ingredients = pd.DataFrame(
    list(zip(_id, id_,  has_sub_ingredients, sub_ingredients, text, percent_min, percent_max, percent, rank, product_name_fr)), 
    columns =['_id', 'denomination', 'has_sub_ingredients', 'sub_ingredients', 'text', 'percent_min', 'percent_max', 'percent', 'rank', 'product_name_fr'])

# %%
df_ingredients
# Out:
#                  _id                                       denomination  \
# 0      0000069162176                                    fr:INGREDIENTES
# 1      0000069162176                                            fr:agua
# 2      0000069162176  fr:harina de tngo tierno carne de Lucio 13 %' ...
# 3      0000069162176                       fr:Lactosa y proteina léctea
# 4      0000069162176                                        en:sal-tree
# ...              ...                                                ...
# 63472  9556041611978                                           en:water
# 63473  9556041611978                                            en:salt
# 63474  9556041611978                                           en:e150a
# 63475  9556041611978                                           en:e150a
# 63476  9556041611978                                            en:e270
#
#       has_sub_ingredients                                    sub_ingredients  \
# 0                     yes  [{'id': 'fr:Quenelles de lucio', 'percent': '4...
# 1                    None                                               None
# 2                    None                                               None
# 3                    None                                               None
# 4                    None                                               None
# ...                   ...                                                ...
# 63472                None                                               None
# 63473                None                                               None
# 63474                None                                               None
# 63475                None                                               None
# 63476                None                                               None
#
#                                                     text percent_min  \
# 0                                           INGREDIENTES        None
# 1                                                   agua        None
# 2      harina de tngo tierno carne de Lucio 13%' acei...        None
# 3                              Lactosa y proteina léctea        None
# 4                                                    sal        None
# ...                                                  ...         ...
# 63472                                                EAU           0
# 63473                                                SEL           0
# 63474                                              e150A           0
# 63475                                              e150C           0
# 63476                                               e270           0
#
#       percent_max percent  rank                    product_name_fr
# 0            None    None   1.0  Quenelles de brochet sauce Nantua
# 1            None    None   2.0  Quenelles de brochet sauce Nantua
# 2            None    None   3.0  Quenelles de brochet sauce Nantua
# 3            None    None   4.0  Quenelles de brochet sauce Nantua
# 4            None    None   5.0  Quenelles de brochet sauce Nantua
# ...           ...     ...   ...                                ...
# 63472      1.0625    None   NaN                Mi Goreng Sauce Wok
# 63473        0.85    None   NaN                Mi Goreng Sauce Wok
# 63474     2.83333    None   NaN                Mi Goreng Sauce Wok
# 63475     1.41667    None   NaN                Mi Goreng Sauce Wok
# 63476     1.41667    None   NaN                Mi Goreng Sauce Wok
#
# [63477 rows x 10 columns]

# %%
def label_ingredient (row):
    if row['denomination'][:2] == 'en' :
        return 0
    return 1

# %%
df_ingredients['unknown_ingredient'] = df_ingredients.apply(lambda row: label_ingredient(row), axis=1)

# %%
df_ingredients.to_csv('O_ingredients.csv')

# %%
df_ingredients['sub_ingredients'][5666]
# Out:
# [{'percent_min': 0,
#   'percent_max': 6.142857142857143,
#   'id': 'fr:aquacultuur',
#   'text': 'aquacultuur'},
#  {'percent_min': 0,
#   'percent_max': 3.0714285714285716,
#   'id': 'fr:aquaculture Land van kweek',
#   'text': 'aquaculture Land van kweek'},
#  {'text': "Pays d'élevage",
#   'id': "fr:Pays d'élevage",
#   'percent_max': 2.047619047619048,
#   'percent_min': 0}]
