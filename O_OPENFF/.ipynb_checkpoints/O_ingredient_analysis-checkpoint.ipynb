# %%
# %pwd
import pandas as pd
import numpy as np
prod=pd.read_csv('O_produits_EAN13.csv',index_col=0)
print('-'*50,'\nPRODUCTS\n','-'*50)
print('\nproduct shape:',prod.shape,'\n')
print('\n',prod.info())

ing=pd.read_csv('O_ingredients.csv', index_col=0)
print('-'*50,'\nINGREDIENTS\n','-'*50)
print('\ningredient shape:',ing.shape,'\n')
print('\n',ing.info())
# Out:
# --------------------------------------------------
# PRODUCTS
#  --------------------------------------------------
#
# product shape: (1100, 38)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1100 entries, 0 to 1099
# Data columns (total 38 columns):
# _id                                                      1100 non-null int64
# categories                                               665 non-null object
# ingredients                                              976 non-null object
# nutriments                                               1100 non-null object
# product_name                                             1090 non-null object
# manufacturing_places                                     213 non-null object
# category_properties                                      1096 non-null object
# ingredients_text                                         646 non-null object
# product_name_fr                                          1063 non-null object
# interface_version_modified                               1098 non-null object
# ingredients_n                                            646 non-null float64
# pnns_groups_1                                            1100 non-null object
# pnns_groups_2                                            1100 non-null object
# cities_tags                                              588 non-null object
# compared_to_category                                     656 non-null object
# countries_hierarchy                                      1100 non-null object
# salt_content                                             976 non-null object
# oil_content                                              976 non-null object
# serving_quantity                                         92 non-null float64
# serving_size                                             92 non-null object
# max_salt_content                                         1100 non-null float64
# min_salt_content                                         1100 non-null float64
# max_oil_content                                          1100 non-null float64
# min_oil_content                                          1100 non-null float64
# oil_type                                                 335 non-null object
# energy_100g                                              1057 non-null float64
# energy_kcal_100g                                         907 non-null float64
# saturated_fat_100g                                       1049 non-null float64
# fat_100g                                                 1053 non-null float64
# carbohydrates_100g                                       1052 non-null float64
# sugars_100g                                              1049 non-null float64
# fruits_vegetables_nuts_estimate_from_ingredients_100g    645 non-null float64
# proteins_100g                                            1057 non-null float64
# sodium_100g                                              1047 non-null float64
# salt_100g                                                1047 non-null float64
# nutrition_score_fr_100g                                  637 non-null float64
# fiber_100g                                               393 non-null float64
# nova_group_100g                                          527 non-null float64
# dtypes: float64(19), int64(1), object(18)
# memory usage: 335.2+ KB
#
#  None
# --------------------------------------------------
# INGREDIENTS
#  --------------------------------------------------
#
# ingredient shape: (63477, 10)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63477 entries, 0 to 63476
# Data columns (total 10 columns):
# _id                    63477 non-null object
# denomination           63477 non-null object
# has_sub_ingredients    9738 non-null object
# sub_ingredients        7575 non-null object
# text                   63477 non-null object
# percent_min            40361 non-null float64
# percent_max            40361 non-null float64
# percent                8888 non-null float64
# rank                   39682 non-null float64
# product_name_fr        63477 non-null object
# dtypes: float64(4), object(6)
# memory usage: 5.3+ MB
#
#  None

# %%
print(ing.shape)
ing.head()
# Out:
# (63477, 10)
#              _id                                       denomination  \
# 0  0000069162176                                    fr:INGREDIENTES
# 1  0000069162176                                            fr:agua
# 2  0000069162176  fr:harina de tngo tierno carne de Lucio 13 %' ...
# 3  0000069162176                       fr:Lactosa y proteina léctea
# 4  0000069162176                                        en:sal-tree
#
#   has_sub_ingredients                                    sub_ingredients  \
# 0                 yes  [{'id': 'fr:Quenelles de lucio', 'percent': '4...
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#                                                 text  percent_min  \
# 0                                       INGREDIENTES          NaN
# 1                                               agua          NaN
# 2  harina de tngo tierno carne de Lucio 13%' acei...          NaN
# 3                          Lactosa y proteina léctea          NaN
# 4                                                sal          NaN
#
#    percent_max  percent  rank                    product_name_fr
# 0          NaN      NaN   1.0  Quenelles de brochet sauce Nantua
# 1          NaN      NaN   2.0  Quenelles de brochet sauce Nantua
# 2          NaN      NaN   3.0  Quenelles de brochet sauce Nantua
# 3          NaN      NaN   4.0  Quenelles de brochet sauce Nantua
# 4          NaN      NaN   5.0  Quenelles de brochet sauce Nantua

# %%
#NUMBER OF UNIQUE PRODUCTS IN INGREDIENTS
len(ing['_id'].unique())
# Out:
# 2707

# %%
# INGREDIENTS POUR LES SEULS PRODUITS DANS OPENFF ET NIELSEN (1100 dans prod)
ing_EAN=ing['_id']

#ing_EAN_inPROD = (ing_EAN in prod['_id'])
ing_EAN_inPROD = np.isin(ing_EAN, prod['_id'])

ing_EAN_inPROD.shape
# Out:
# (63477,)

# %%
#ing_EAN_true= ing_EAN in prod['_id']
ing_EAN_true = np.isin(ing_EAN, prod['_id'])

ing.shape
# Out:
# (63477, 10)

# %%
#MOST FREQUENT INGREDIENTS (IN ENGLISH)
#NUMBER OF PRODUCTS 1100 in prod /2500 i ing
ing_u_en=ing[['denomination','_id']].groupby(['denomination']).count().sort_values('_id', ascending=False)
print('type:',type(ing_u_en))
print('number of different ingredients:', ing_u_en.shape)
ing_u_en.head(50)
# Out:
# type: <class 'pandas.core.frame.DataFrame'>
# number of different ingredients: (7824, 1)
#                                 _id
# denomination
# en:salt                        4090
# en:water                       3218
# en:sugar                       1974
# en:onion                       1668
# en:crushed-tomato              1220
# en:garlic                      1057
# en:sunflower-oil               1038
# en:spice                        942
# en:tomato                       930
# en:colza-oil                    912
# en:carrot                       863
# en:flavouring                   804
# en:e330                         803
# en:acid                         798
# en:modified-corn-starch         679
# en:thickener                    634
# en:alcohol-vinegar              603
# en:pepper                       594
# en:e415                         580
# en:wheat-flour                  559
# en:natural-flavouring           555
# en:vinegar                      527
# en:basil                        516
# en:colour                       484
# en:preservative                 469
# en:antioxidant                  419
# en:extra-virgin-olive-oil       413
# en:parsley                      387
# en:milk                         360
# en:celery                       345
# en:mustard-seed                 336
# en:bell-pepper                  329
# en:herb                         298
# en:mustard                      289
# en:modified-starch              273
# en:e412                         272
# en:egg-yolk                     271
# en:stabiliser                   271
# en:dextrose                     269
# en:e160c                        264
# en:vegetable                    259
# en:chili-pepper                 257
# en:white-wine                   248
# en:acidity-regulator            235
# en:tomato-pulp                  235
# en:double-concentrated-tomato   229
# en:e270                         226
# en:herbs-and-spices             221
# en:beef-meat                    221
# en:concentrated-lemon-juice     221

# %%
print(ing_u_en['tomato'in index])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-bb7b0e39f8a9> in <module>
# ----> 1 print(ing_u_en['tomato'in index])
#
# NameError: name 'index' is not defined

# %%
sample=[1,5,10,20,30,40,50,75,100,150,200,250,500]
print('number of ingredients for the ingredient in position')
for i in sample:
    print(i,':',ing_u_en.loc[[i]['_id']])
# Out:
# number of ingredients for the ingredient in position
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-fe3dc59c6d2b> in <module>
#       2 print('number of ingredients for the ingredient in position')
#       3 for i in sample:
# ----> 4     print(i,':',ing_u_en.loc[[i]['_id']])
#
# TypeError: list indices must be integers or slices, not str

# %%
ing_u_en[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-ab66275fbd4c> in <module>
# ----> 1 ing_u_en[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
ing_u_en.plot.hist(bins=1000,xlim=(0,200))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:572: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x000002317BF4B548> has a label of '_id' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
#MOST FREQUENT INGREDIENTS
#NUMBER OF PRODUCTS 1100 in prod /2500 i ing
ing_u_enfr=ing[['denomination','text','_id']].groupby(['denomination','text']).count().sort_values('_id', ascending=False)
ing_u_enfr.head(30)
# Out:
#                                                        _id
# denomination              text
# en:salt                   sel                         3781
# en:water                  eau                         2762
# en:sugar                  sucre                       1815
# en:onion                  oignons                      957
# en:garlic                 ail                          946
# en:sunflower-oil          huile de tournesol           937
# en:colza-oil              huile de colza               698
# en:acid                   acidifiant                   690
# en:spice                  épices                       676
# en:onion                  oignon                       589
# en:carrot                 carottes                     585
# en:e330                   acide citrique               585
# en:alcohol-vinegar        vinaigre d'alcool            582
# en:pepper                 poivre                       567
# en:vinegar                vinaigre                     480
# en:flavouring             arômes                       476
# en:basil                  basilic                      472
# en:thickener              épaississant                 414
# en:preservative           conservateur                 387
# en:tomato                 tomates                      383
# en:colour                 colorant                     375
# en:crushed-tomato         concentré de tomates         369
# en:e415                   gomme xanthane               358
# en:parsley                persil                       357
# en:crushed-tomato         concentré de tomate          345
# en:antioxidant            antioxydant                  334
# en:water                  Eau                          331
# en:extra-virgin-olive-oil huile d'olive vierge extra   307
# en:modified-corn-starch   amidon transformé de maïs    291
# en:tomato                 tomate                       285
