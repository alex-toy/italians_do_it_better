# %%
import pandas as pd
import numpy as np

# %%
#################################################
# 0) FUNCTIONS                                  #
#################################################

# %%
import sys
sys.path.append('../')
from func import *

#DEFINED FUNCTIONS :
    
#unique_clean(data,col,pr=0)

#df_with_text(data,col,text)
#text_in_df(data,col,text)
#two_text_in_df(data,col,text1,text2)
#two_text_in_df(data,col,text1,text2='')

#values_U_not_nan(data,col_name)
#not_nan_get_values(data,col_name,pr=0)
#not_nan_get_index(data, col_name, pr=0)
#nan_get_index(data, col_name, pr=0)

#is_not_decimal(a)
#is_not_13(a)
#split_text_left(text_to_split,text)
#split_item_left(st)
#split_item_right(st)

#find_weight(text):     #s = re.compile('\d+G') extracts '210G'

# %%
##########################################
# 1) IMPORT DATA
##########################################

# %%
####################################################################################
# 1.1) IMPORT M_PROD_MFINAL (merge Nielsen and Openfood facts)

prod = pd.read_csv('../M_MERGE/output_data/M_PROD_FINAL.csv',index_col=0)
prod['O_EAN13'] = prod['O_EAN13'].astype(str)
prod['N_EAN13'] = prod['N_EAN13'].astype(str)
prod['O_EAN13']=prod['O_EAN13'].apply(lambda row : row[0:-2])
prod['N_EAN13']=prod['N_EAN13'].apply(lambda row : row[0:-2])
print('-'*50,'\nPRODUCTS\n','-'*50)
print('\nproduct shape:',prod.shape,'\n')
print('\n',prod.info())
# Out:
# --------------------------------------------------
# PRODUCTS
#  --------------------------------------------------
#
# product shape: (3979, 74)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3979 entries, 0 to 3978
# Data columns (total 74 columns):
# O_EAN13                                                    3979 non-null object
# O_product_name_fr                                          3305 non-null object
# O_product_name                                             3419 non-null object
# O_brands                                                   3434 non-null object
# O_brands_tags_str                                          3434 non-null object
# O_brands_tags                                              3434 non-null object
# O_serving_size                                             539 non-null object
# O_serving_quantity                                         539 non-null float64
# O_countries_hierarchy                                      3434 non-null object
# O_cities_tags                                              2460 non-null object
# O_manufacturing_places                                     753 non-null object
# O_purchase_places                                          1170 non-null object
# O_countries_tags                                           3434 non-null object
# O_categories                                               2995 non-null object
# O_category_properties                                      3434 non-null object
# O_pnns_groups_1                                            3433 non-null object
# O_pnns_groups_2                                            3434 non-null object
# O_compared_to_category                                     2970 non-null object
# O_interface_version_modified                               3430 non-null object
# O_ingredients_n                                            2542 non-null float64
# O_ingredients_text                                         2542 non-null object
# O_ingredients                                              3267 non-null object
# O_salt_content                                             3267 non-null object
# O_max_salt_content                                         3434 non-null float64
# O_min_salt_content                                         3434 non-null float64
# O_oil_content                                              3267 non-null object
# O_max_oil_content                                          3434 non-null float64
# O_min_oil_content                                          3434 non-null float64
# O_oil_type                                                 948 non-null object
# O_nutriments                                               3434 non-null object
# O_energy_100g                                              3309 non-null float64
# O_energy_kcal_100g                                         2691 non-null float64
# O_saturated_fat_100g                                       3280 non-null float64
# O_fat_100g                                                 3291 non-null float64
# O_carbohydrates_100g                                       3293 non-null float64
# O_sugars_100g                                              3286 non-null float64
# O_fruits_vegetables_nuts_estimate_from_ingredients_100g    2541 non-null float64
# O_proteins_100g                                            3307 non-null float64
# O_sodium_100g                                              3281 non-null float64
# O_salt_100g                                                3281 non-null float64
# O_nutrition_score_fr_100g                                  2816 non-null float64
# O_fiber_100g                                               1557 non-null float64
# O_nova_group_100g                                          2320 non-null float64
# O_COUNT                                                    3434 non-null float64
# O_date_modified                                            3430 non-null float64
# O_BRANDS_UPPER                                             3434 non-null object
# S_brands                                                   1975 non-null object
# S_BRAND                                                    1975 non-null object
# S_BRAND_TYPE                                               1975 non-null object
# S_BRANDS_UPPER                                             1975 non-null object
# Unnamed: 0.1                                               1443 non-null float64
# index                                                      1443 non-null float64
# N_EAN13                                                    3979 non-null object
# N_MARQUE                                                   1443 non-null object
# N_SAME_PRODUCT                                             1443 non-null object
# N_GAMME                                                    1432 non-null object
# N_RECETTES                                                 1432 non-null object
# N_ORGANIC                                                  1443 non-null object
# N_FORMAT                                                   1432 non-null object
# N_WEIGHT_num                                               1443 non-null float64
# N_EMBALLAGE                                                1443 non-null object
# N_COMPTE                                                   1432 non-null object
# N_STD/PROMO                                                1432 non-null object
# N_Ventes_Valeur_2019                                       1443 non-null float64
# N_Ventes_Valeur_2018                                       1443 non-null float64
# N_ITEM                                                     1432 non-null object
# N_NIELSEN_DESCRIPTION                                      1443 non-null object
# N_INITIAL_INDEX                                            1443 non-null float64
# N_CATEGORY                                                 1443 non-null object
# N_COUNT                                                    1443 non-null float64
# I_ITEM                                                     1272 non-null object
# I_CATEGORY                                                 1112 non-null object
# I_Ventes_Volume_2018                                       1443 non-null float64
# I_Ventes_Volume_2019                                       1443 non-null float64
# dtypes: float64(30), object(44)
# memory usage: 2.3+ MB
#
#  None

# %%
O_EAN13_U = unique_clean(prod,'O_EAN13')

print(O_EAN13_U[0])
type(O_EAN13_U[0])
# Out:
# number of  O_EAN13  unique (non null) values:  3431
# <class 'list'>
#
# 87157215
# str

# %%
####################################################################################
# 1.2) IMPORT INGREDIENTS (extracted form products in M_PROD_MFINAL)

ing = pd.read_csv('../O_OPENFF/output_data/O_INGREDIENTS_preprocessed.csv', index_col=0)
ing['O_EAN13'] = ing['O_EAN13'].astype(str)
print('-'*50,'\nINGREDIENTS\n','-'*50)
print('\ningredient shape:',ing.shape,'\n')
print('\n',ing.info())
# Out:
# --------------------------------------------------
# INGREDIENTS
#  --------------------------------------------------
#
# ingredient shape: (39114, 18)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39114 entries, 0 to 39113
# Data columns (total 18 columns):
# O_EAN13                 39114 non-null object
# id_ingredient           39114 non-null object
# has_sub_ingredients     5631 non-null object
# sub_ingredients         4888 non-null object
# text                    39114 non-null object
# percent_min             28684 non-null float64
# percent_max             28684 non-null float64
# percent                 6188 non-null float64
# rank                    27771 non-null float64
# product_name_fr         38105 non-null object
# unknown_ingredient      39114 non-null int64
# id_language             39114 non-null object
# id_ing_sub_ing          4888 non-null object
# sub_ing_dict            4775 non-null object
# sub_ingredients_id      4770 non-null object
# sub_ingredients_fr      0 non-null float64
# sub_ingredients_text    4768 non-null object
# ing_id_sub_ing_id       39114 non-null object
# dtypes: float64(5), int64(1), object(12)
# memory usage: 5.7+ MB
#
#  None

# %%
# load marine file
tomato = pd.read_excel('../I_ITALIANS/Ingredient_analyse tomates.xlsx')
for col in tomato.columns :
    tomato.rename(columns={col : col.strip()}, inplace=True)

tomato['NORMALISED']=tomato['NORMALISED'].str.strip()

tomato=tomato[~tomato['NORMALISED'].isna()]
tomato=tomato[tomato['NORMALISED']!='other']
tomato=tomato[['id_ingredient','NORMALISED','SCORE']]

#filt = (~tomato['SCORE'].isna()) & (tomato['SCORE'] != 'Na')

#tomato['SCORE'][filt].astype(float)
tomato.shape
# Out:
# (168, 3)

# %%
tomato.sort_values(by='SCORE', ascending=False).head(20)
# Out:
#                                          id_ingredient NORMALISED  SCORE
# 304                              fr:Tomates italiennes     tomato    9.0
# 300  fr:Tomates cultivées dans le pays Marmandais e...     tomato    9.0
# 31                             fr:tomates Cœur de Bœuf     tomato    8.0
# 50                                   en:organic-tomato     tomato    8.0
# 26                                   en:fresh-tomatoes     tomato    8.0
# 297                            fr:Tomates Cœur de Bœuf     tomato    8.0
# 53                           fr:tomates pelées en cube     tomato    7.0
# 305                        fr:Tomates passées au tamis     tomato    7.0
# 7                                      en:tomato-cubes     tomato    7.0
# 112                                   fr:tomates cubes     tomato    7.0
# 70             fr:dés de toma- d' Concentré de tomates     tomato    7.0
# 121                                 fr:tomates en cube     tomato    7.0
# 261  fr:Pulpe de tomates fraîches avec morceaux et ...     tomato    6.0
# 262  fr:Pulpe de tomates fraîches avec morceaux et ...     tomato    6.0
# 260  fr:Pulpe de tomates fraîches avec morceaux et ...     tomato    6.0
# 263  fr:Pulpe de tomates fraîches avec morceaux et ...     tomato    6.0
# 22   fr:Pulpe de tomates fraîches avec morceaux et ...     tomato    6.0
# 264                     fr:Pulpe de tomates italiennes     tomato    6.0
# 259  fr:Pulpe de tomates fraiches avec morceaux et ...     tomato    6.0
# 173  fr:pulpe de tomates fraîches avec morceaux et ...     tomato    6.0

# %%
###########################################
# MERGE TOMATO into INGREDIENTS
###########################################

# %%
ing_tomato = ing.merge(tomato, left_on='id_ingredient', right_on='id_ingredient', how='left')

# %%
ing_tomato
# Out:
#              O_EAN13                      id_ingredient has_sub_ingredients  \
# 0           10127780               fr:coulis-de-tomates                 NaN
# 1           10127780                       en:aubergine                 NaN
# 2           10127780          en:extra-virgin-olive-oil                 NaN
# 3           10127780                           en:onion                 NaN
# 4           10127780                          en:carrot                 NaN
# ...              ...                                ...                 ...
# 39109  9556041612555                   en:yeast-extract                 NaN
# 39110  9556041612555                        en:cardamom                 NaN
# 39111  9556041612555                     en:cumin-seeds                 NaN
# 39112  9556041612555  fr:FEUILLES DE CITRON VERT KAFFIR                 NaN
# 39113  9556041612555                          en:pepper                 NaN
#
#       sub_ingredients                            text  percent_min  \
# 0                 NaN                Coulis de Tomate       78.900
# 1                 NaN                      aubergines        9.700
# 2                 NaN      huile extra-vierge d'olive        3.900
# 3                 NaN                         oignons        1.875
# 4                 NaN                        carottes        1.200
# ...               ...                             ...          ...
# 39109             NaN               EXTRAIT DE LEVURE        0.000
# 39110             NaN                       CARDAMONE        0.000
# 39111             NaN                           CUMIN        0.000
# 39112             NaN  FEUILLES DE CITRON VERT KAFFIR        0.000
# 39113             NaN                          POIVRE        0.000
#
#        percent_max  percent  rank                      product_name_fr  \
# 0        78.900000     78.9   1.0  sauce tomate et aubergines grillées
# 1         9.700000      9.7   2.0  sauce tomate et aubergines grillées
# 2         3.900000      3.9   3.0  sauce tomate et aubergines grillées
# 3         3.900000      NaN   4.0  sauce tomate et aubergines grillées
# 4         3.175000      NaN   5.0  sauce tomate et aubergines grillées
# ...            ...      ...   ...                                  ...
# 39109     5.945048      NaN  14.0                     Curry rouge thaï
# 39110     5.487736      NaN  15.0                     Curry rouge thaï
# 39111     5.095755      NaN  16.0                     Curry rouge thaï
# 39112     4.756038      NaN  17.0                     Curry rouge thaï
# 39113     4.458786      NaN  18.0                     Curry rouge thaï
#
#        unknown_ingredient id_language id_ing_sub_ing sub_ing_dict  \
# 0                       1          fr            NaN          NaN
# 1                       0          en            NaN          NaN
# 2                       0          en            NaN          NaN
# 3                       0          en            NaN          NaN
# 4                       0          en            NaN          NaN
# ...                   ...         ...            ...          ...
# 39109                   0          en            NaN          NaN
# 39110                   0          en            NaN          NaN
# 39111                   0          en            NaN          NaN
# 39112                   1          fr            NaN          NaN
# 39113                   0          en            NaN          NaN
#
#       sub_ingredients_id  sub_ingredients_fr sub_ingredients_text  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 39109                NaN                 NaN                  NaN
# 39110                NaN                 NaN                  NaN
# 39111                NaN                 NaN                  NaN
# 39112                NaN                 NaN                  NaN
# 39113                NaN                 NaN                  NaN
#
#                        ing_id_sub_ing_id NORMALISED  SCORE
# 0                   fr:coulis-de-tomates     tomato    4.0
# 1                           en:aubergine        NaN    NaN
# 2              en:extra-virgin-olive-oil        NaN    NaN
# 3                               en:onion        NaN    NaN
# 4                              en:carrot        NaN    NaN
# ...                                  ...        ...    ...
# 39109                   en:yeast-extract        NaN    NaN
# 39110                        en:cardamom        NaN    NaN
# 39111                     en:cumin-seeds        NaN    NaN
# 39112  fr:FEUILLES DE CITRON VERT KAFFIR        NaN    NaN
# 39113                          en:pepper        NaN    NaN
#
# [39114 rows x 20 columns]

# %%
ean_tomato_ing=[]
for ean in O_EAN13_U :
    temp = ing[ing['O_EAN13'] == ean]
    temp_tomato=temp[temp['NORMALISED']=='tomato']
    if temp.shape[0]!=0:
        print(temp_tomato.shape[0])
        #tomato_ing.append(ean)
        #for i in range(len(temp_tomato)):
        #    tomato_ing.append(temp['NOTATION'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NORMALISED'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-8837dcaa96a6> in <module>
#       2 for ean in O_EAN13_U :
#       3     temp = ing[ing['O_EAN13'] == ean]
# ----> 4     temp_tomato=temp[temp['NORMALISED']=='tomato']
#       5     if temp.shape[0]!=0:
#       6         print(temp_tomato.shape[0])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NORMALISED'

# %%
###########################################
# IMPORT INGREDIENTS FEATURES INTO PROD
###########################################

# %%
prod['basil']=prod['O_ingredients_text'].apply(lambda row: 1 if ('basil' in str(row)) else 0 )

inprod['basil']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3974    0
# 3975    0
# 3976    0
# 3977    0
# 3978    0
# Name: basil, Length: 3979, dtype: int64

# %%
ing_to_feature=['basil','sugar','amidon','carrot','flavouring', 'preservative','thickener']
for ing in ing_to_feature:
    prod[ing]=prod['O_ingredients_text'].apply(lambda row: 1 if (ing in str(row)) else 0 )

# %%
prod
# Out:
#           O_EAN13                      O_product_name_fr  \
# 0        87157215  Tomato Ketchup Heinz Ouverture En Bas
# 1        50157846       Heinz Squeeze Sauce Salade Cream
# 2        87157635                         Tomato Ketchup
# 3     13000001014                 Organic Tomato Ketchup
# 4     13000526807                         Heinz 57 Sauce
# ...           ...                                    ...
# 3974            n                                    NaN
# 3975            n                                    NaN
# 3976            n                                    NaN
# 3977            n                                    NaN
# 3978            n                                    NaN
#
#                              O_product_name O_brands O_brands_tags_str  \
# 0     Tomato Ketchup Heinz Ouverture En Bas    Heinz         ['heinz']
# 1          Heinz Squeeze Sauce Salade Cream    Heinz         ['heinz']
# 2                            Tomato Ketchup    Heinz         ['heinz']
# 3                    Organic Tomato Ketchup    Heinz         ['heinz']
# 4                                     Sauce    Heinz         ['heinz']
# ...                                     ...      ...               ...
# 3974                                    NaN      NaN               NaN
# 3975                                    NaN      NaN               NaN
# 3976                                    NaN      NaN               NaN
# 3977                                    NaN      NaN               NaN
# 3978                                    NaN      NaN               NaN
#
#      O_brands_tags O_serving_size  O_serving_quantity  \
# 0        ['heinz']            NaN                 NaN
# 1        ['heinz']           15 g                15.0
# 2        ['heinz']            NaN                 NaN
# 3        ['heinz']            NaN                 NaN
# 4        ['heinz']  1 Tbsp (17 g)                17.0
# ...            ...            ...                 ...
# 3974           NaN            NaN                 NaN
# 3975           NaN            NaN                 NaN
# 3976           NaN            NaN                 NaN
# 3977           NaN            NaN                 NaN
# 3978           NaN            NaN                 NaN
#
#                   O_countries_hierarchy O_cities_tags  ... I_CATEGORY  \
# 0                         ['en:france']           NaN  ...        NaN
# 1                         ['en:france']            []  ...        NaN
# 2                         ['en:france']            []  ...        NaN
# 3                         ['en:france']           NaN  ...        NaN
# 4     ['en:france', 'en:united-states']           NaN  ...        NaN
# ...                                 ...           ...  ...        ...
# 3974                                NaN           NaN  ...        NaN
# 3975                                NaN           NaN  ...        NaN
# 3976                                NaN           NaN  ...        NaN
# 3977                                NaN           NaN  ...        NaN
# 3978                                NaN           NaN  ...        NaN
#
#      I_Ventes_Volume_2018 I_Ventes_Volume_2019 basil sugar amidon carrot  \
# 0                     NaN                  NaN     0     0      0      0
# 1                     NaN                  NaN     0     0      0      0
# 2                     NaN                  NaN     0     0      0      0
# 3                     NaN                  NaN     0     0      0      0
# 4                     NaN                  NaN     0     0      0      0
# ...                   ...                  ...   ...   ...    ...    ...
# 3974                  0.0                  0.0     0     0      0      0
# 3975                  0.0                  0.0     0     0      0      0
# 3976                  0.0                  0.0     0     0      0      0
# 3977                  0.0                  0.0     0     0      0      0
# 3978                  0.0                  0.0     0     0      0      0
#
#      flavouring preservative  thickener
# 0             0            0          0
# 1             0            0          0
# 2             0            0          0
# 3             0            0          0
# 4             0            1          0
# ...         ...          ...        ...
# 3974          0            0          0
# 3975          0            0          0
# 3976          0            0          0
# 3977          0            0          0
# 3978          0            0          0
#
# [3979 rows x 81 columns]

# %%
prod['O_ingredients_text'] = prod['O_ingredients_text'].apply(lambda row : row.strip())
check=('basil' in prod['O_ingredients_text'])
check
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-0d504629c967> in <module>
# ----> 1 prod['O_ingredients_text'] = prod['O_ingredients_text'].apply(lambda row : row.strip())
#       2 check=('basil' in prod['O_ingredients_text'])
#       3 check
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-120-0d504629c967> in <lambda>(row)
# ----> 1 prod['O_ingredients_text'] = prod['O_ingredients_text'].apply(lambda row : row.strip())
#       2 check=('basil' in prod['O_ingredients_text'])
#       3 check
#
# AttributeError: 'float' object has no attribute 'strip'

# %%
O_ingredients_text                                         2542 non-null object
O_ingredients

# %%
pwd
# Out:
# '/Users/alexei/Desktop/italians_do_it_better/O_OPENFF'

# %%
#Save O_PROD_FINAL with ingredeint features
prod.to_csv('../PRODUCT_FEATURIZED.csv')
prod.to_excel('../PRODUCT_FEATURIZED.xlsx')
