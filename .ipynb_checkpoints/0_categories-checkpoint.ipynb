# %%
# !pwd
# Out:
# /Users/alexei/italians_do_it_better

# %%
# !ls
# Out:
# N_NIELSEN                               O_produits_EAN13_categories.csv
# N_nielsen.ipynb                         README.md
# O_ingredients.csv                       categories.ipynb
# O_ingredients.ipynb                     ingredients.csv
# O_produits.csv                          mongo db - champs à sélectionner.docx
# O_produits.ipynb                        nielsen.csv
# O_produits_EAN13.csv

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('O_produits_EAN13.csv')

# %%
df["CATEGORY"] = "AUTRE"
df["SUB_CATEGORY"] = "AUTRE"

# %%
df['ingredients_text'].fillna(" ", inplace=True)
df['product_name'].fillna(" ", inplace=True)

# %%
contains_tomate = df['ingredients_text'].str.contains('Tomate', regex=True, flags=re.IGNORECASE)
df.loc[:, 'CATEGORY'][contains_tomate] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
is_provencale = df['product_name'].str.contains('provençale|provence|provencale', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_provencale] = 'PROVENCALE'
df.loc[:, 'CATEGORY'][is_provencale] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_puttanesca = df['product_name'].str.contains('Puttanesca', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_puttanesca] = 'PUTTANESCA'
df.loc[:, 'CATEGORY'][is_puttanesca] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_arrabbiata = df['product_name'].str.contains('arrabbiata|arrabiata', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_arrabbiata] = 'ARRABBIATA'
df.loc[:, 'CATEGORY'][is_arrabbiata] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_pomodoro = df['product_name'].str.contains('tomates?', regex=True, flags=re.IGNORECASE) & df['product_name'].str.contains('basilic', regex=True, flags=re.IGNORECASE) 
df.loc[:, 'SUB_CATEGORY'][is_pomodoro] = 'POMODORO'
df.loc[:, 'CATEGORY'][is_pomodoro] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_norma = df['product_name'].str.contains('tomates?', regex=True, flags=re.IGNORECASE) & df['product_name'].str.contains('aubergine', regex=True, flags=re.IGNORECASE) 
df.loc[:, 'SUB_CATEGORY'][is_norma] = 'NORMA'
df.loc[:, 'CATEGORY'][is_norma] = 'TOMATES'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_bolognese = df['product_name'].str.contains('bolognese|bolognaise', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_bolognese] = 'BOLOGNESE'
df.loc[:, 'CATEGORY'][is_bolognese] = 'VIANDE_POISSON'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_chorizo = df['product_name'].str.contains('chorizo', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_chorizo] = 'CHORIZO'
df.loc[:, 'CATEGORY'][is_chorizo] = 'VIANDE_POISSON'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_poulet = df['product_name'].str.contains('poulet', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_poulet] = 'POULET'
df.loc[:, 'CATEGORY'][is_poulet] = 'VIANDE_POISSON'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_poisson = df['product_name'].str.contains('poisson', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_poisson] = 'POISSON'
df.loc[:, 'CATEGORY'][is_poisson] = 'VIANDE_POISSON'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_genovese = df['product_name'].str.contains('genovese', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_genovese] = 'GENOVESE'
df.loc[:, 'CATEGORY'][is_genovese] = 'PESTI'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_pesto_rosso = df['product_name'].str.contains('pesto rosso', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_pesto_rosso] = 'PESTO_ROSSO'
df.loc[:, 'CATEGORY'][is_pesto_rosso] = 'PESTI'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_pesto_calabrese = df['product_name'].str.contains('pesto calabrese', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_pesto_calabrese] = 'PESTO_CALABRESE'
df.loc[:, 'CATEGORY'][is_pesto_calabrese] = 'PESTI'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_pesto_citron = df['product_name'].str.contains('pesto citron', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_pesto_citron] = 'PESTO_CITRON'
df.loc[:, 'CATEGORY'][is_pesto_citron] = 'PESTI'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
is_carbonara = df['product_name'].str.contains('carbonara', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_carbonara] = 'CARBONARA'
df.loc[:, 'CATEGORY'][is_carbonara] = 'FROMAGE'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#probleme!!! ecrase sauces pesto!!!

# %%
is_fromages = df['product_name'].str.contains('fromages|fromage', regex=True, flags=re.IGNORECASE)
df.loc[:, 'SUB_CATEGORY'][is_fromages] = 'FROMAGES'
df.loc[:, 'CATEGORY'][is_fromages] = 'FROMAGE'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df[df['CATEGORY'] == 'ARRABBIATA']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, _id, categories, ingredients, nutriments, product_name, manufacturing_places, category_properties, ingredients_text, product_name_fr, interface_version_modified, ingredients_n, pnns_groups_1, pnns_groups_2, cities_tags, compared_to_category, countries_hierarchy, salt_content, oil_content, serving_quantity, serving_size, max_salt_content, min_salt_content, max_oil_content, min_oil_content, oil_type, energy_100g, energy_kcal_100g, saturated_fat_100g, fat_100g, carbohydrates_100g, sugars_100g, fruits_vegetables_nuts_estimate_from_ingredients_100g, proteins_100g, sodium_100g, salt_100g, nutrition_score_fr_100g, fiber_100g, nova_group_100g, CATEGORY, SUB_CATEGORY]
# Index: []
#
# [0 rows x 41 columns]

# %%
df[50:70]
# Out:
#     Unnamed: 0            _id  \
# 50          50  3021690028102
# 51          51  3021690028614
# 52          52  3021690029048
# 53          53  3021690029055
# 54          54  3021690029345
# 55          55  3021690029550
# 56          56  3038352870207
# 57          57  3038352870825
# 58          58  3038352870924
# 59          59  3038352871303
# 60          60  3038352871310
# 61          61  3038352871327
# 62          62  3038352872300
# 63          63  3038352874809
# 64          64  3038352874908
# 65          65  3038354170800
# 66          66  3038354179506
# 67          67  3038354180809
# 68          68  3038354181707
# 69          69  3038354190105
#
#                                            categories  \
# 50                    Epicerie, Sauces, Sauces tomate
# 51                    Epicerie, Sauces, Sauces tomate
# 52                    Epicerie, Sauces, Sauces tomate
# 53  Epicerie, Produits à la viande, Sauces, Sauces...
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57  Epicerie, Produits à la viande, Sauces, Sauces...
# 58                    Epicerie, Sauces, Sauces tomate
# 59                    Epicerie, Sauces, Sauces tomate
# 60  Epicerie, Produits à la viande, Sauces, Sauces...
# 61  Epicerie, Produits à la viande, Sauces, Sauces...
# 62  Epicerie, Produits à la viande, Sauces, Sauces...
# 63                Epicerie, Sauces, Sauces pour pâtes
# 64                 Epicerie, Sauces, Sauces carbonara
# 65                                                NaN
# 66                     Epicerie, Sauces, Sauces Pesto
# 67  Epicerie, Produits à la viande, Sauces, Sauces...
# 68                    Epicerie, Sauces, Sauces tomate
# 69  Epicerie, Produits à la viande, Sauces, Sauces...
#
#                                           ingredients  \
# 50  ['Purée de tomate', 'huile de tournesol', 'suc...
# 51  ['tomate', 'purée de tomate mi-réduite', 'oign...
# 52                                                 []
# 53  ['Purée de tomate mi-réduite', 'viandes', 'eau...
# 54                                                NaN
# 55                                                NaN
# 56                                                 []
# 57                                                 []
# 58  ['tomates fraiches', 'sucre', 'amidon transfor...
# 59  ['concentré de tomates', 'eau', 'légumes', 'ca...
# 60  ['Pulpe de tomate', 'concentré de tomate', 'vi...
# 61  ['Pulpe de tomates', 'concentré de tomates', '...
# 62  ['Fan', 'viande de bœuf français', 'concentré ...
# 63  ['Eau', '_fromages_', '_crème_', 'amidons tran...
# 64  ['Eau', 'lardons fumés', 'viande de porc', 'se...
# 65                                                 []
# 66  ['Huile de tournesol', 'poivrons rouges et jau...
# 67  ['Pulpe de tomates avec morceaux et purée de t...
# 68  ['Pulpe de tomates avec morceaux et purée de t...
# 69  ['Pulpe de tomates', 'concentré de tomate', 'v...
#
#                                            nutriments  \
# 50  {'sugars_unit': 'g', 'nova-group': 4, 'fiber_1...
# 51  {'saturated-fat': 0.3, 'nutrition-score-fr_ser...
# 52  {'nutrition-score-fr_serving': 4, 'saturated-f...
# 53  {'carbon-footprint-from-known-ingredients_serv...
# 54  {'salt_unit': 'g', 'sugars_100g': 6.1, 'sugars...
# 55  {'sugars_unit': 'g', 'salt_unit': 'g', 'sugars...
# 56  {'proteins_unit': '', 'carbohydrates_100g': 6....
# 57  {'saturated-fat': 1.8, 'nutrition-score-fr_ser...
# 58  {'sugars_unit': '', 'nova-group': 4, 'fiber_10...
# 59  {'sugars_unit': 'g', 'fiber_100g': 2.7, 'nova-...
# 60  {'carbohydrates_100g': 6.3, 'proteins_unit': '...
# 61  {'nova-group': 4, 'sugars_100g': 5.1, 'salt_un...
# 62  {'sugars_unit': '', 'nova-group_100g': 4, 'sal...
# 63  {'proteins_100g': 4.6, 'carbohydrates': 4.4, '...
# 64  {'saturated-fat_value': 5.9, 'saturated-fat_un...
# 65  {'proteins': 5.6, 'energy_value': 343, 'protei...
# 66  {'fat': 30, 'fruits-vegetables-nuts-estimate-f...
# 67  {'saturated-fat_value': 1, 'saturated-fat_unit...
# 68  {'nutrition-score-fr_serving': 1, 'carbon-foot...
# 69  {'sodium_unit': 'g', 'saturated-fat_100g': 0.9...
#
#                                 product_name manufacturing_places  \
# 50                              Sauce tomate                  NaN
# 51                  Sauce tomate Ratatouille                  NaN
# 52                       Ma sauce tomate bio                  NaN
# 53                          Sauce bolognaise                  NaN
# 54         Sauce italienne à la viande rôtie                  NaN
# 55         Sauce italienne a la viande rôtie                  NaN
# 56              Brick 1KG Pesto Vert Panzani                  NaN
# 57         sauce bolognaise au boeuf rissolé                  NaN
# 58                Sauce aux tomates fraîches                  NaN
# 59  Sauce Tomate cuisinée aux petits légumes                  NaN
# 60                          Sauce bolognaise                  NaN
# 61                          Sauce bolognaise                  NaN
# 62          Sauce Bolognaise 100 % Pur Boeuf                  NaN
# 63                          Sauce 4 Fromages                  NaN
# 64                         Panzani Carbonara                  NaN
# 65                 Panzani Sauce Bolo Ball S                  NaN
# 66                    Pesto poivrons grillés               Italie
# 67                       Bolo Balls au boeuf                  NaN
# 68                          Bolo Balls Spicy                  NaN
# 69                                Bolognaise                  NaN
#
#                                   category_properties  \
# 50                                                 {}
# 51                                                 {}
# 52                                                 {}
# 53  {'ciqual_food_name:en': 'Tomato sauce, with me...
# 54                                                 {}
# 55                                                 {}
# 56                                                 {}
# 57  {'ciqual_food_name:fr': 'Sauce tomate à la via...
# 58                                                 {}
# 59                                                 {}
# 60  {'ciqual_food_name:en': 'Tomato sauce, with me...
# 61  {'ciqual_food_name:en': 'Tomato sauce, with me...
# 62  {'ciqual_food_name:fr': 'Sauce tomate à la via...
# 63                                                 {}
# 64  {'ciqual_food_name:fr': 'Sauce carbonara, prée...
# 65                                                 {}
# 66  {'ciqual_food_name:en': 'Sauce, pesto, prepack...
# 67                                                 {}
# 68                                                 {}
# 69  {'ciqual_food_name:en': 'Tomato sauce, with me...
#
#                                      ingredients_text  \
# 50  Purée de tomate 90%, huile de tournesol, sucre...
# 51  tomate 33%, purée de tomate mi-réduite 30%, oi...
# 52
# 53  Purée de tomate mi-réduite à base de concentré...
# 54
# 55
# 56
# 57
# 58  purée de tomates fraiches (91%), sucre, amidon...
# 59  concentré de tomates (38%), eau, légumes : 10%...
# 60  Pulpe de tomate et concentré de tomate 54%, vi...
# 61  Pulpe de tomates et concentré de tomates (55% ...
# 62  Fan, viande de bœuf français (28%), concentré ...
# 63  Eau, _fromages_ 7 % (mascarpone 2,3 %, fromage...
# 64  Eau, lardons fumés 16% (viande de porc, sel, d...
# 65
# 66  Huile de tournesol 27%, poivrons rouges et jau...
# 67  Pulpe de tomates avec morceaux et purée de tom...
# 68  Pulpe de tomates avec morceaux et purée de tom...
# 69  Pulpe de tomates et concentré de tomate (55%),...
#
#                              product_name_fr  ... sugars_100g  \
# 50                              Sauce tomate  ...         5.5
# 51                  Sauce tomate Ratatouille  ...         6.5
# 52                       Ma sauce tomate bio  ...         2.6
# 53                          Sauce bolognaise  ...         2.1
# 54         Sauce italienne à la viande rôtie  ...         6.1
# 55         Sauce italienne a la viande rôtie  ...         6.1
# 56                                       NaN  ...         2.1
# 57         sauce bolognaise au boeuf rissolé  ...         5.8
# 58                Sauce aux tomates fraîches  ...         7.1
# 59  Sauce Tomate cuisinée aux petits légumes  ...         8.1
# 60                          Sauce bolognaise  ...         4.6
# 61                          Sauce bolognaise  ...         5.1
# 62          Sauce Bolognaise 100 % Pur Boeuf  ...         5.6
# 63                          Sauce 4 Fromages  ...         0.8
# 64                         Panzani Carbonara  ...         0.8
# 65                 Panzani Sauce Bolo Ball S  ...         4.9
# 66                    Pesto poivrons grillés  ...         3.2
# 67                       Bolo Balls au boeuf  ...         4.9
# 68                          Bolo Balls Spicy  ...         4.9
# 69                                Bolognaise  ...         5.1
#
#     fruits_vegetables_nuts_estimate_from_ingredients_100g proteins_100g  \
# 50                                          90.000000               1.2
# 51                                          80.300000               1.2
# 52                                                NaN               1.6
# 53                                          67.900000               3.5
# 54                                                NaN               3.4
# 55                                                NaN               3.4
# 56                                                NaN               7.7
# 57                                                NaN               5.0
# 58                                          91.000000               0.9
# 59                                          50.321429               2.7
# 60                                          54.000000               5.1
# 61                                         110.000000               4.6
# 62                                          16.800000               6.0
# 63                                           0.000000               4.6
# 64                                           0.200000               4.0
# 65                                                NaN               5.6
# 66                                          29.000000               3.9
# 67                                          54.000000               5.6
# 68                                          53.000000               8.4
# 69                                         110.000000               4.6
#
#    sodium_100g salt_100g nutrition_score_fr_100g fiber_100g nova_group_100g  \
# 50    0.468000   1.17000                     1.0        0.6             4.0
# 51    0.400000   1.00000                     0.0        NaN             3.0
# 52    0.400000   1.00000                     4.0        0.5             NaN
# 53    0.480000   1.20000                     2.0        0.5             3.0
# 54    0.480000   1.20000                     NaN        NaN             NaN
# 55    0.480000   1.20000                     NaN        NaN             NaN
# 56    1.200000   3.00000                     NaN        NaN             NaN
# 57    0.520000   1.30000                     4.0        1.6             NaN
# 58    0.584000   1.46000                     1.0        1.1             4.0
# 59    1.120000   2.80000                     9.0        2.7             4.0
# 60    0.520000   1.30000                     3.0        NaN             4.0
# 61    0.480000   1.20000                    -1.0        NaN             4.0
# 62    0.344000   0.86000                     4.0        0.5             4.0
# 63    0.600456   1.50114                    12.0        0.5             4.0
# 64    0.720000   1.80000                    13.0        0.4             4.0
# 65    0.680000   1.70000                     NaN        1.8             NaN
# 66    1.000000   2.50000                    17.0        NaN             4.0
# 67    0.680000   1.70000                     4.0        1.8             4.0
# 68    0.520000   1.30000                     1.0        2.2             4.0
# 69    0.464000   1.16000                    -1.0        0.0             4.0
#
#           CATEGORY  SUB_CATEGORY
# 50         TOMATES         AUTRE
# 51         TOMATES         AUTRE
# 52           AUTRE         AUTRE
# 53  VIANDE_POISSON     BOLOGNESE
# 54           AUTRE         AUTRE
# 55           AUTRE         AUTRE
# 56           AUTRE         AUTRE
# 57  VIANDE_POISSON     BOLOGNESE
# 58         TOMATES         AUTRE
# 59         FROMAGE      FROMAGES
# 60  VIANDE_POISSON     BOLOGNESE
# 61  VIANDE_POISSON     BOLOGNESE
# 62  VIANDE_POISSON     BOLOGNESE
# 63         FROMAGE      FROMAGES
# 64         FROMAGE     CARBONARA
# 65           AUTRE         AUTRE
# 66           AUTRE         AUTRE
# 67         TOMATES         AUTRE
# 68         TOMATES         AUTRE
# 69  VIANDE_POISSON     BOLOGNESE
#
# [20 rows x 41 columns]

# %%
df.to_csv('O_produits_EAN13_categories.csv')

# %%
df_N_FRANCE = pd.read_csv('N_NIELSEN/N_FRANCE.csv')
df_N_FRANCE_EAN13 = np.array(df_N_FRANCE['EAN13_num'])

df_FRANCE_FEC_Pesto = pd.read_csv('N_NIELSEN/N_FRANCE_FEC_Pesto.csv')
df_FRANCE_FEC_Pesto_EAN13 = np.array(df_FRANCE_FEC_Pesto['EAN13_num'])

df_id = np.array(df['_id'])

# %%
df_FRANCE_FEC_Pesto.head()
# Out:
#    Unnamed: 0               CATEGORY                  MKT_SEGMENT  \
# 0         231  SAUCES POUR FECULENTS  HMSM + PROXI + DRIVE + SDMP
# 1         232  SAUCES POUR FECULENTS  HMSM + PROXI + DRIVE + SDMP
# 2         234  SAUCES POUR FECULENTS  HMSM + PROXI + DRIVE + SDMP
# 3         237  SAUCES POUR FECULENTS  HMSM + PROXI + DRIVE + SDMP
# 4         240  SAUCES POUR FECULENTS  HMSM + PROXI + DRIVE + SDMP
#
#                KPI      EAN13_num           MARQUE         RECETTES  ORGANIC  \
# 0  Ventes Volume    3038359009204          PANZANI  PEST BASIL PARM        0
# 1  Ventes Volume    3038359009211          PANZANI  PESTO TOM SECHE        0
# 2  Ventes Volume    3021690018899  ZAPETTI BUITONI       PESTO VERD        0
# 3  Ventes Volume    8076809542012          BARILLA       PESTO VERD        0
# 4  Ventes Volume    3038352870207          PANZANI       PESTO VERD        0
#
#    WEIGHT_num EMBALLAGE  ... 4 S 11/08/19 4 S 08/09/19 4 S 06/10/19  \
# 0         120  COUPELLE  ...       1211.8       1131.1        762.3
# 1         120  COUPELLE  ...        169.1        158.2        132.2
# 2          40      DOSE  ...          0.0          0.0          0.0
# 3         500   DOY PAC  ...          1.0          2.5          1.5
# 4        1000   DOY PAC  ...         16.0         12.0          4.0
#
#   4 S 03/11/19 4 S 01/12/19  4 S 29/12/19         EAN13  WEIGHT  \
# 0        661.4        576.6         595.4  3.038359e+12   120.0
# 1        131.8        128.4         139.2  3.038359e+12   120.0
# 2          0.0          0.0           0.0  3.021690e+12    40.0
# 3          0.5          2.0           1.0  8.076810e+12   500.0
# 4          4.0          0.0           3.0  3.038353e+12  1000.0
#
#                                  NIELSEN_DESCRIPTION  INITIAL_INDEX
# 0  COUPELLE PANZANI SA PANZANI PESTO PF PEST BASI...            281
# 1  COUPELLE PANZANI SA PANZANI PESTO PF PESTO TOM...            282
# 2  FECULENTS DOSE ZAPETTI ZAPETTI BUITONI PESTO F...            287
# 3  SAUCES POUR FECULENTS DOY PAC BARILLA PESTO MF...            293
# 4  FECULENTS DOY PAC PANZANI SA PANZANI PESTO TGF...            300
#
# [5 rows x 47 columns]

# %%
df_N_FRANCE_EAN13_in_df_id = np.isin(df_N_FRANCE_EAN13, df_id)
df_id_in_df_N_FRANCE_EAN13 = np.isin(df_id, df_N_FRANCE_EAN13)

# %%
df_id_in_df_N_FRANCE_EAN13
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
df_FRANCE_FEC_Pesto_EAN13_in_df_id = np.isin(df_FRANCE_FEC_Pesto_EAN13, df_id)
df_id_in_df_FRANCE_FEC_Pesto_EAN13 = np.isin(df_id, df_FRANCE_FEC_Pesto_EAN13)

# %%
df_FRANCE_FEC_Pesto_EAN13_in_df_id.sum() / len(df_FRANCE_FEC_Pesto_EAN13) * 100
# Out:
# 77.38095238095238

# %%
df_id_in_df_FRANCE_FEC_Pesto_EAN13.sum() / len(df_FRANCE_FEC_Pesto_EAN13) * 100
# Out:
# 4.551820728291316

# %%
df_FRANCE_FEC_Pesto['NIELSEN_DESCRIPTION'][0]
# Out:
# 'COUPELLE PANZANI SA PANZANI PESTO PF PEST BASIL PARM 1CT 120G * NON BIO'
