# %%
from pymongo import MongoClient
import pandas as pd
client = MongoClient()
db = client.openfoodfacts
collection = db.products

# %%
c_f = collection.find().limit(2)
data = pd.DataFrame(list(c_f))

# %%
proj = { 
    'product_name_fr' : 1, 
    'ingredients' : 1, 
    'salt_content' : 1, 
    'oil_content' : 1, 
    'product_name' : 1,
    'nutriments' : 1,
    'compared_to_category' : 1,
    'interface_version_modified' : 1
}

addFields = { 
    
    'ingredients' : "$ingredients.text",
    
    'salt_content' : {
            '$filter' : {
               'input' : "$ingredients",
               'as' : "item",
               'cond' : { '$or' : [ 
                   { '$eq' : [ "$$item.text", 'Sel' ] }, 
                   { '$eq' : [ "$$item.text", 'sel' ] },
                   { '$eq' : [ "$$item.text", 'SEL' ] },
                   { '$eq' : [ "$$item.text", 'VINAGE SEL' ] },
                   { '$eq' : [ "$$item.text", 'sel marin' ] },
                   { '$eq' : [ "$$item.text", 'Sel marin' ] },
                   { '$eq' : [ "$$item.text", 'salt' ] },
                   { '$eq' : [ "$$item.text", 'Salt' ] }] }
            }
    },
    
    
    'oil_content': {
            '$filter' : {
               'input' : "$ingredients",
               'as' : "item",
               'cond' : { '$or' : [ { 
                   '$eq' : [ "$$item.text", 'huile d\'olive extra vierge' ] }, {
                   '$eq' : [ "$$item.text", 'huile extra vierge d\'olive' ] }, { 
                   '$eq' : [ "$$item.text", 'huile d\'olive extra-vierge' ] }, { 
                   '$eq' : [ "$$item.text", 'Huile d\'olive vierge extra' ] }, { 
                   '$eq' : [ "$$item.text", 'Huile d\'olive extra vierge' ] }, {
                   '$eq' : [ "$$item.text", 'huile dolive* vierge exta' ] }, { 
                   '$eq' : [ "$$item.text", 'huile d\'olive vierge extraite à froid' ] }, { 
                   '$eq' : [ "$$item.text", 'huile d\'olive vierge' ] }, {
                   '$eq' : [ "$$item.text", 'huile d\'olive' ] }, {
                   '$eq' : [ "$$item.text", 'Huile d\'olive' ] }, {
                   '$eq' : [ "$$item.text", 'huile de colza' ] }, { 
                   '$eq' : [ "$$item.text", 'huile d\'olive vierge extra extraite à froid' ] }, { 
                   '$eq' : [ "$$item.text", 'huile de tournesol' ] }, {
                   '$eq' : [ "$$item.text", 'Huile de tournesol' ] }, {
                   '$eq' : [ "$$item.text", 'huile de tournesol désodorisée' ] }, {
                   '$eq' : [ "$$item.text", 'Extra Virgin Olive Oil' ] }, { 
                   '$eq' : [ "$$item.text", 'Huile de palme' ] }, {
                   '$eq' : [ "$$item.text", 'natives Olivenöl extra' ] }, { 
                   '$eq' : [ "$$item.text", 'Sonnenblumenöl' ] }, { 
                   '$eq' : [ "$$item.text", 'Olivenöl' ] }, { 
                   '$eq' : [ "$$item.text", 'Huile Végétale' ] }, {
                   '$eq' : [ "$$item.text", 'Huile de colza' ] }, {
                   '$eq' : [ "$$item.text", 'huile végétale de colza' ] }, { 
                   '$eq' : [ "$$item.text", 'Huile végétale de colza' ] }, {
                   '$eq' : [ "$$item.text", 'Huile d\'olive vierge extra' ] } ] 
                    }
            }
    },
}




match = {
    
    'ingredients' : { 
        "$elemMatch" : { 
            "text" : { '$regex' : "tomate*", '$options' : "i" },
        } 
    },
    
    "product_name_fr" : { '$regex' : "sauce*", '$options' : "i" }
    
}



c_f = collection.aggregate([
    { '$match' : match } ,
    { '$project' : proj },
    { '$addFields' : addFields }
])

data = pd.DataFrame(list(c_f))

# %%
data.head(5)
# Out:
#              _id                                         nutriments  \
# 0  0000069162176  {'salt_unit': '', 'energy': 586, 'proteins': 4...
# 1       00005010  {'energy-kcal_value': 106, 'sodium_100g': 0.16...
# 2       00021036  {'salt': 0.6, 'fiber_100g': 3.1, 'carbohydrate...
# 3       00089227  {'fiber': 1.7, 'fruits-vegetables-nuts-estimat...
# 4  0011110791474  {'sodium_100g': 2, 'energy-kcal_value': 100, '...
#
#                          product_name interface_version_modified  \
# 0   Quenelles de brochet sauce Nantua              20150316.jqm2
# 1      Organic tomato sauce bolognese              20150316.jqm2
# 2     Tomato & Gorgonzola pasta sauce              20150316.jqm2
# 3        Tomato & Sausage Pasta Sauce                   20120622
# 4  Peri peri chili culinary hot sauce              20150316.jqm2
#
#   compared_to_category                                        ingredients  \
# 0    en:pike-quenelles  [INGREDIENTES, agua, harina de tngo tierno car...
# 1  en:bolognese-sauces  [Tomato puree, beef mince meat, carrots, extra...
# 2                  NaN  [sauce à la tomate, à Itoignon kJ et à la caro...
# 3     en:tomato-sauces  [Pulpe de tomate, Saucisse de porc, Concentré ...
# 4            en:sauces  [Water, red bell peppers, distilled vinegar, t...
#
#                       product_name_fr  \
# 0   Quenelles de brochet sauce Nantua
# 1      Organic tomato sauce bolognese
# 2     Tomato & Gorgonzola pasta sauce
# 3        Tomato & Sausage Pasta Sauce
# 4  Peri peri chili culinary hot sauce
#
#                                         salt_content  \
# 0                                                 []
# 1  [{'id': 'en:salt', 'text': 'salt', 'vegetarian...
# 2                                                 []
# 3  [{'id': 'en:salt', 'vegan': 'yes', 'text': 'Se...
# 4  [{'percent_min': 0, 'rank': 6, 'percent_max': ...
#
#                                          oil_content
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'from_palm_oil': 'no', 'id': 'en:extra-virgi...
# 4                                                 []

# %%
max_salt_content = []
for l in data['salt_content'] :
    if len(l) > 0 and 'percent_max' in l[0]  :
        max_salt_content.append(l[0]['percent_max'])
    else :
        max_salt_content.append(0)
        
data['max_salt_content'] = max_salt_content

min_salt_content = []
for l in data['salt_content'] :
    if len(l) > 0 and 'percent_min' in l[0]  :
        min_salt_content.append(l[0]['percent_min'])
    else :
        min_salt_content.append(0)
        
data['min_salt_content'] = min_salt_content

max_oil_content = []
for l in data['oil_content'] :
    if len(l) > 0 and 'percent_max' in l[0]  :
        max_oil_content.append(l[0]['percent_max'])
    else :
        max_oil_content.append(0)
        
data['max_oil_content'] = max_oil_content

min_oil_content = []
for l in data['oil_content'] :
    if len(l) > 0 and 'percent_min' in l[0]  :
        min_oil_content.append(l[0]['percent_min'])
    else :
        min_oil_content.append(0)
        
data['min_oil_content'] = min_oil_content

oil_type = []
for l in data['oil_content'] :
    if len(l) > 0 and 'percent_min' in l[0]  :
        oil_type.append(l[0]['text'])
    else :
        oil_type.append("")
        
data['oil_type'] = oil_type

salt_100g = []
for l in data['nutriments'] :
    if len(l) > 0 and 'salt_100g' in l :
        salt_100g.append(l['salt_100g'])
    else :
        salt_100g.append(None)
        
data['salt_100g'] = salt_100g

fiber_100g = []
for l in data['nutriments'] :
    if len(l) > 0 and 'fiber_100g' in l :
        fiber_100g.append(l['fiber_100g'])
    else :
        fiber_100g.append(None)
        
data['fiber_100g'] = fiber_100g

sodium_100g = []
for l in data['nutriments'] :
    if len(l) > 0 and 'sodium_100g' in l :
        sodium_100g.append(l['sodium_100g'])
    else :
        sodium_100g.append(None)
        
data['sodium_100g'] = sodium_100g

# %%
data
# Out:
#                 _id                                         nutriments  \
# 0     0000069162176  {'salt_unit': '', 'energy': 586, 'proteins': 4...
# 1          00005010  {'energy-kcal_value': 106, 'sodium_100g': 0.16...
# 2          00021036  {'salt': 0.6, 'fiber_100g': 3.1, 'carbohydrate...
# 3          00089227  {'fiber': 1.7, 'fruits-vegetables-nuts-estimat...
# 4     0011110791474  {'sodium_100g': 2, 'energy-kcal_value': 100, '...
# ...             ...                                                ...
# 2702       93201834  {'energy-kcal_unit': 'kcal', 'sugars': 46, 'pr...
# 2703  9300681008403  {'fat_unit': 'g', 'nova-group_serving': 4, 'sa...
# 2704  9556041601214  {'carbohydrates_unit': '', 'saturated-fat_100g...
# 2705  9556041611121  {'sodium': 1.08, 'proteins_serving': 0, 'salt'...
# 2706  9556041611978  {'fat_serving': 0.74, 'nova-group': 4, 'nova-g...
#
#                             product_name interface_version_modified  \
# 0      Quenelles de brochet sauce Nantua              20150316.jqm2
# 1         Organic tomato sauce bolognese              20150316.jqm2
# 2        Tomato & Gorgonzola pasta sauce              20150316.jqm2
# 3           Tomato & Sausage Pasta Sauce                   20120622
# 4     Peri peri chili culinary hot sauce              20150316.jqm2
# ...                                  ...                        ...
# 2702                           BBQ Sauce              20150316.jqm2
# 2703                   Sweet chili sauce              20150316.jqm2
# 2704       Ayam Sardines In Tomato Sauce              20150316.jqm2
# 2705             Sauce aigre-douce Ayam™                   20190830
# 2706                 Mi Goreng Sauce Wok              20150316.jqm2
#
#              compared_to_category  \
# 0               en:pike-quenelles
# 1             en:bolognese-sauces
# 2                             NaN
# 3                en:tomato-sauces
# 4                       en:sauces
# ...                           ...
# 2702           en:barbecue-sauces
# 2703  fr:sauces-tomates-pimentees
# 2704  en:sardines-in-tomato-sauce
# 2705     en:sweet-and-sour-sauces
# 2706                          NaN
#
#                                             ingredients  \
# 0     [INGREDIENTES, agua, harina de tngo tierno car...
# 1     [Tomato puree, beef mince meat, carrots, extra...
# 2     [sauce à la tomate, à Itoignon kJ et à la caro...
# 3     [Pulpe de tomate, Saucisse de porc, Concentré ...
# 4     [Water, red bell peppers, distilled vinegar, t...
# ...                                                 ...
# 2702  [sugar, water, white vinegar, tomato paste mal...
# 2703  [Sucre, eau, concentré de tomates, vinaigre, l...
# 2704  [POISSON DE TYPE SARDINES, SAUCE TOMATE, PILCH...
# 2705  [EAU, SUCRE, ÉPAISSISSANT, CONCENTRÉ DE TOMATE...
# 2706  [EAU, OIGNONS, SAUCE SOJA EPAISSE, AIL, HUILE ...
#
#                          product_name_fr  \
# 0      Quenelles de brochet sauce Nantua
# 1         Organic tomato sauce bolognese
# 2        Tomato & Gorgonzola pasta sauce
# 3           Tomato & Sausage Pasta Sauce
# 4     Peri peri chili culinary hot sauce
# ...                                  ...
# 2702                           BBQ Sauce
# 2703                   Sweet chili sauce
# 2704       Ayam Sardines In Tomato Sauce
# 2705             Sauce aigre-douce Ayam™
# 2706                 Mi Goreng Sauce Wok
#
#                                            salt_content  \
# 0                                                    []
# 1     [{'id': 'en:salt', 'text': 'salt', 'vegetarian...
# 2                                                    []
# 3     [{'id': 'en:salt', 'vegan': 'yes', 'text': 'Se...
# 4     [{'percent_min': 0, 'rank': 6, 'percent_max': ...
# ...                                                 ...
# 2702  [{'vegetarian': 'yes', 'percent_max': 16.66666...
# 2703  [{'text': 'sel', 'id': 'en:salt', 'percent_min...
# 2704  [{'vegan': 'yes', 'vegetarian': 'yes', 'text':...
# 2705  [{'percent_min': 0, 'vegetarian': 'yes', 'vega...
# 2706  [{'percent_min': 0, 'vegetarian': 'yes', 'rank...
#
#                                             oil_content max_salt_content  \
# 0                                                    []                0
# 1                                                    []          1.02307
# 2                                                    []                0
# 3     [{'from_palm_oil': 'no', 'id': 'en:extra-virgi...                0
# 4                                                    []          16.6667
# ...                                                 ...              ...
# 2702                                                 []          16.6667
# 2703                                                 []              2.5
# 2704                                                 []                0
# 2705                                                 []          16.6667
# 2706                                                 []              8.5
#
#      min_salt_content max_oil_content min_oil_content oil_type  salt_100g  \
# 0                   0               0               0              4.9000
# 1           0.0826429               0               0              0.4000
# 2                   0               0               0              0.6000
# 3                   0               0               0              0.7900
# 4                   0               0               0              5.0000
# ...               ...             ...             ...      ...        ...
# 2702                0               0               0              1.1000
# 2703                0               0               0              2.6162
# 2704                0               0               0              0.9200
# 2705                0               0               0              2.7000
# 2706                0               0               0              2.3000
#
#       fiber_100g  sodium_100g
# 0            0.5      1.96000
# 1            NaN      0.16000
# 2            3.1      0.24000
# 3            1.7      0.31600
# 4            NaN      2.00000
# ...          ...          ...
# 2702         NaN      0.44000
# 2703         NaN      1.04648
# 2704         NaN      0.36800
# 2705         NaN      1.08000
# 2706         NaN      0.92000
#
# [2707 rows x 17 columns]
