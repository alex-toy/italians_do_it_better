# %%
import pandas as pd
import numpy as np
import re

# %%
# %pwd
# Out:
# '/Users/alexei/italians_do_it_better/M_MERGE'

# %%
#################################################
# 1) FUNCTIONS                                  #
#################################################

# %%
import sys
sys.path.append('../')
from func import *

#DEFINED FUNCTIONS :
    
#unique_clean(data,col,pr=0)

#df_with_text(data,col,text)
#text_in_df(data,col,text)
#two_text_in_df(data,col,text1,text2)
#two_text_in_df(data,col,text1,text2='')

#values_U_not_nan(data,col_name)
#not_nan_get_values(data,col_name,pr=0)
#not_nan_get_index(data, col_name, pr=0)
#nan_get_index(data, col_name, pr=0)

#is_not_decimal(a)
#is_not_13(a)
#split_text_left(text_to_split,text)
#split_item_left(st)
#split_item_right(st)

#find_weight(text):     #s = re.compile('\d+G') extracts '210G'

# %%
#################################################
# 2) O_PROD from Open food Facts (EAN13)           #
#################################################

# %%
#Import from openFF
df_O_PROD = pd.read_csv('../O_OPENFF/output_data/O_data_EAN13.csv', index_col=0)

df_O_PROD['O_EAN13'] = df_O_PROD['O_EAN13'].astype(str)

#Creation of a column with ones to count product matches with groupby method
df_O_PROD['O_COUNT'] = 1
df_O_PROD['O_date_modified'] = df_O_PROD['O_interface_version_modified'].apply(lambda row : split_text_left(row, '.'))

# %%
df_O_PROD['O_date_modified']
# Out:
# 0       20150316
# 1       20120622
# 2       20120622
# 3       20150316
# 4       20150316
#           ...
# 1095    20150316
# 1096    20190830
# 1097    20150316
# 1098    20120622
# 1099    20150316
# Name: O_date_modified, Length: 1100, dtype: object

# %%
df_O_PROD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1100 entries, 0 to 1099
# Data columns (total 40 columns):
# O_EAN13                                                    1100 non-null object
# O_categories                                               665 non-null object
# O_ingredients                                              976 non-null object
# O_nutriments                                               1100 non-null object
# O_product_name                                             1090 non-null object
# O_manufacturing_places                                     213 non-null object
# O_category_properties                                      1096 non-null object
# O_ingredients_text                                         646 non-null object
# O_product_name_fr                                          1063 non-null object
# O_interface_version_modified                               1098 non-null object
# O_ingredients_n                                            646 non-null float64
# O_pnns_groups_1                                            1100 non-null object
# O_pnns_groups_2                                            1100 non-null object
# O_cities_tags                                              588 non-null object
# O_compared_to_category                                     656 non-null object
# O_countries_hierarchy                                      1100 non-null object
# O_salt_content                                             976 non-null object
# O_oil_content                                              976 non-null object
# O_serving_quantity                                         92 non-null float64
# O_serving_size                                             92 non-null object
# O_max_salt_content                                         1100 non-null float64
# O_min_salt_content                                         1100 non-null float64
# O_max_oil_content                                          1100 non-null float64
# O_min_oil_content                                          1100 non-null float64
# O_oil_type                                                 335 non-null object
# O_energy_100g                                              1057 non-null float64
# O_energy_kcal_100g                                         907 non-null float64
# O_saturated_fat_100g                                       1049 non-null float64
# O_fat_100g                                                 1053 non-null float64
# O_carbohydrates_100g                                       1052 non-null float64
# O_sugars_100g                                              1049 non-null float64
# O_fruits_vegetables_nuts_estimate_from_ingredients_100g    645 non-null float64
# O_proteins_100g                                            1057 non-null float64
# O_sodium_100g                                              1047 non-null float64
# O_salt_100g                                                1047 non-null float64
# O_nutrition_score_fr_100g                                  637 non-null float64
# O_fiber_100g                                               393 non-null float64
# O_nova_group_100g                                          527 non-null float64
# O_COUNT                                                    1100 non-null int64
# O_date_modified                                            1100 non-null object
# dtypes: float64(19), int64(1), object(20)
# memory usage: 352.3+ KB

# %%
#Adding O_ in front of each column name of df_O_PROD
if not df_O_PROD.columns[0][0:2] == 'O_' :
    for c in df_O_PROD.columns :
        df_O_PROD.rename(columns={c : 'O_' + c}, inplace=True)

# %%
df_O_PROD.head()
# Out:
#          O_EAN13                                       O_categories  \
# 0  3017239003969  Epicerie, Sauces, Sauces aux légumes, Sauces a...
# 1  3017239003976  Epicerie, Sauces, Sauces aux légumes, Sauces a...
# 2  3017239003983  Epicerie, Sauces, Sauces Pesto, Sauces Pesto R...
# 3  3017239003990                                                NaN
# 4  3017239004003  Epicerie, Sauces, Sauces tomate, Sauces tomate...
#
#                                        O_ingredients  \
# 0  ['Tomate', 'olive noire', "huile d'olive", 'câ...
# 1  ['olive verte égouttée', 'huile de tournesol',...
# 2  ['Tomate', 'olive', 'huile de tournesol', 'pom...
# 3                                                 []
# 4  ['Tomate', 'champignon', 'olive verte égouttée...
#
#                                         O_nutriments  \
# 0  {'energy-kcal_100g': 122, 'carbohydrates_value...
# 1  {'nova-group_100g': 4, 'energy-kj_100g': 1086,...
# 2  {'nutrition-score-fr_serving': 7, 'saturated-f...
# 3  {'saturated-fat': 1, 'sodium_unit': 'g', 'satu...
# 4  {'carbohydrates': 4.1, 'proteins_100g': 1.5, '...
#
#                        O_product_name O_manufacturing_places  \
# 0         Sauce aux Olives Provençale                 France
# 1   Sauce aux olives façon pesto vert                    NaN
# 2  Sauce aux olives façon pesto rosso                 France
# 3      Sauce aux Olives Citron Confit                    NaN
# 4        Sauce aux olives champignons                 France
#
#                                O_category_properties  \
# 0                                                 {}
# 1                                                 {}
# 2  {'ciqual_food_name:fr': 'Sauce pesto rosso, pr...
# 3                                                 {}
# 4  {'ciqual_food_name:en': 'Tomato sauce, w mushr...
#
#                                   O_ingredients_text  \
# 0  Tomate (51%), olive noire (36%), huile d'olive...
# 1  olive verte égouttée (33%), huile de tournesol...
# 2  Tomate 46%, olive 18% (dont olive verte égoutt...
# 3                                                NaN
# 4  Tomate (36 %), champignon (24 %), olive verte ...
#
#                     O_product_name_fr O_interface_version_modified  ...  \
# 0         Sauce aux Olives Provençale                20150316.jqm2  ...
# 1   Sauce aux olives façon pesto vert                     20120622  ...
# 2  Sauce aux olives façon pesto rosso                     20120622  ...
# 3                                 NaN                20150316.jqm2  ...
# 4        Sauce aux olives champignons                20150316.jqm2  ...
#
#    O_sugars_100g O_fruits_vegetables_nuts_estimate_from_ingredients_100g  \
# 0            2.7                                          53.166667
# 1            2.6                                           0.000000
# 2            4.3                                          46.000000
# 3            3.5                                                NaN
# 4            2.5                                          36.000000
#
#   O_proteins_100g O_sodium_100g O_salt_100g O_nutrition_score_fr_100g  \
# 0             1.3          0.84        2.10                      10.0
# 1             1.7          0.30        0.75                       8.0
# 2             2.8          0.48        1.20                       7.0
# 3             1.4          0.56        1.40                       NaN
# 4             1.5          0.48        1.20                       7.0
#
#   O_fiber_100g O_nova_group_100g  O_COUNT O_date_modified
# 0          NaN               3.0        1        20150316
# 1          NaN               4.0        1        20120622
# 2          NaN               4.0        1        20120622
# 3          NaN               NaN        1        20150316
# 4          NaN               4.0        1        20150316
#
# [5 rows x 40 columns]

# %%
###################################################
# 3) Cration of N_PROD from Nielsen               #
###################################################

# %%
###################################################
# 3.1) N_PROD from Nielsen (select MARKET and KPI)

# %%
#Import from NIELSEN (8 MARKET * 17 KPI * 1425 EAN13)
df_N_ALL = pd.read_csv('../N_NIELSEN/output_data/N_ALL_DATA_preprocessed.csv',index_col=0)
df_N_ALL['EAN13']=df_N_ALL['EAN13'].astype(str)
df_N_ALL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209040 entries, 0 to 209039
# Data columns (total 51 columns):
# MARKET_INITIAL         8 non-null object
# FACTS                  136 non-null object
# NIELSEN_DESCRIPTION    208896 non-null object
# EMBALLAGE              208624 non-null object
# MARQUE                 206448 non-null object
# GAMME                  194752 non-null object
# FORMAT                 194752 non-null object
# RECETTES               194752 non-null object
# COMPTE                 194752 non-null object
# STD/PROMO              194752 non-null object
# ITEM                   194752 non-null object
# CAM_AN-1               208896 non-null float64
# DERNIER_CAM            208896 non-null float64
# 4_S_28/01/18           208896 non-null float64
# 4_S_25/02/18           208896 non-null float64
# 4_S_25/03/18           208896 non-null float64
# 4_S_22/04/18           208896 non-null float64
# 4_S_20/05/18           208896 non-null float64
# 4_S_17/06/18           208896 non-null float64
# 4_S_15/07/18           208896 non-null float64
# 4_S_12/08/18           208896 non-null float64
# 4_S_09/09/18           208896 non-null float64
# 4_S_07/10/18           208896 non-null float64
# 4_S_04/11/18           208896 non-null float64
# 4_S_02/12/18           208896 non-null float64
# 4_S_30/12/18           208896 non-null float64
# 4_S_27/01/19           208896 non-null float64
# 4_S_24/02/19           208896 non-null float64
# 4_S_24/03/19           208896 non-null float64
# 4_S_21/04/19           208896 non-null float64
# 4_S_19/05/19           208896 non-null float64
# 4_S_16/06/19           208896 non-null float64
# 4_S_14/07/19           208896 non-null float64
# 4_S_11/08/19           208896 non-null float64
# 4_S_08/09/19           208896 non-null float64
# 4_S_06/10/19           208896 non-null float64
# 4_S_03/11/19           208896 non-null float64
# 4_S_01/12/19           208896 non-null float64
# 4_S_29/12/19           208896 non-null float64
# EAN13                  209040 non-null object
# MARKET                 209040 non-null object
# KPI                    209032 non-null object
# CATEGORY               208896 non-null object
# ORGANIC                208896 non-null object
# WEIGHT                 194616 non-null object
# INITIAL_INDEX          209040 non-null int64
# EAN_promo              2040 non-null object
# EAN13_num              209040 non-null int64
# SAME_PRODUCT           194752 non-null object
# LONG_BRAND             198560 non-null object
# WEIGHT_num             209040 non-null int64
# dtypes: float64(28), int64(3), object(20)
# memory usage: 82.9+ MB

# %%
df_N_ALL.columns
# Out:
# Index(['MARKET_INITIAL', 'FACTS', 'NIELSEN_DESCRIPTION', 'EMBALLAGE', 'MARQUE',
#        'GAMME', 'FORMAT', 'RECETTES', 'COMPTE', 'STD/PROMO', 'ITEM',
#        'CAM_AN-1', 'DERNIER_CAM', '4_S_28/01/18', '4_S_25/02/18',
#        '4_S_25/03/18', '4_S_22/04/18', '4_S_20/05/18', '4_S_17/06/18',
#        '4_S_15/07/18', '4_S_12/08/18', '4_S_09/09/18', '4_S_07/10/18',
#        '4_S_04/11/18', '4_S_02/12/18', '4_S_30/12/18', '4_S_27/01/19',
#        '4_S_24/02/19', '4_S_24/03/19', '4_S_21/04/19', '4_S_19/05/19',
#        '4_S_16/06/19', '4_S_14/07/19', '4_S_11/08/19', '4_S_08/09/19',
#        '4_S_06/10/19', '4_S_03/11/19', '4_S_01/12/19', '4_S_29/12/19', 'EAN13',
#        'MARKET', 'KPI', 'CATEGORY', 'ORGANIC', 'WEIGHT', 'INITIAL_INDEX',
#        'EAN_promo', 'EAN13_num', 'SAME_PRODUCT', 'LONG_BRAND', 'WEIGHT_num'],
#       dtype='object')

# %%
df_N_ALL[['MARKET', 'KPI', 'CATEGORY', 'EMBALLAGE', 'MARQUE', 'SAME_PRODUCT', 'DERNIER_CAM']].head(20)
# Out:
#                          MARKET            KPI CATEGORY EMBALLAGE  MARQUE  \
# 0   HMSM | PROXI | DRIVE | SDMP            NaN      NaN       NaN     NaN
# 1   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume      NaN       NaN     NaN
# 2   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE       NaN     NaN
# 3   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB     NaN
# 4   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB  AUT_MQ
# 5   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB  AUT_MQ
# 6   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB  AUT_MQ
# 7   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB  AUT_MQ
# 8   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   AUT_EMB  AUT_MQ
# 9   HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      BRIC     NaN
# 10  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      BRIC     MDD
# 11  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   BTE_FER     NaN
# 12  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   BTE_FER  AUT_MQ
# 13  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   BTE_FER  AUT_MQ
# 14  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE   BTE_FER  AUT_MQ
# 15  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      DOSE     NaN
# 16  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      DOSE  AUT_MQ
# 17  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      DOSE  AUT_MQ
# 18  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      DOSE  AUT_MQ
# 19  HMSM | PROXI | DRIVE | SDMP  Ventes_Volume  AUT_SCE      DOSE  AUT_MQ
#
#                                          SAME_PRODUCT  DERNIER_CAM
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN     586027.1
# 3                                                 NaN       1408.6
# 4                                                 NaN       1408.6
# 5   AUT_MQ | SCE_CLAS | CITRON_VERT_PIMENT_DOUX | ...          2.7
# 6   AUT_MQ | SCE_CLAS | CURRY_JAUNE_THAI | AUT_EMB...        803.5
# 7   AUT_MQ | SCE_CLAS | CURRY_VERT_&_LEGUMES | AUT...        602.5
# 8        AUT_MQ | SCE_CLAS | YUZU | AUT_EMB | NON_BIO          0.0
# 9                                                 NaN      30922.6
# 10                                                NaN      30922.6
# 11                                                NaN        972.0
# 12                                                NaN        972.0
# 13  AUT_MQ | SCE_CLAS | CEPES_&_AU_JUS_DE_TRUFFES_...        662.8
# 14  AUT_MQ | SCE_CLAS | PERIGUEUX_TRUFFEE_A_1% | B...        309.2
# 15                                                NaN       5236.5
# 16                                                NaN       5236.5
# 17  AUT_MQ | SCE_CLAS | BEURRE_BLANC_&_CITRON_CONF...       2470.1
# 18          AUT_MQ | SCE_CLAS | CEPE | DOSE | NON_BIO       1276.6
# 19  AUT_MQ | SCE_CLAS | CREME_AUX_POIREAUX | DOSE ...        587.7

# %%
# list of all the markets
MARKET_U = pd.DataFrame(unique_clean(df_N_ALL,'MARKET'), columns =['MARKET'])
market_short = ['France','Hyper-Supermarkets','Supermarkets','Supermarkets small','Supermarkets big','Paris Region','MONOPRIX shops','FRANPRIX shops']
MARKET_U['MARKET_SHORT']=market_short
comments=['including hard discounter and cash & carry','Hyper > 4.000 m2 (to be confirmed)','','', '','','city center large shops','city center medium shops']
MARKET_U['MARKET_COMMENTS'] = comments
MARKET_U
# Out:
# number of  MARKET  unique (non null) values:  8
# <class 'list'>
#                         MARKET        MARKET_SHORT  \
# 0  HMSM | PROXI | DRIVE | SDMP              France
# 1               ENSEIGNES_HMSM  Hyper-Supermarkets
# 2                 ENSEIGNES_SM        Supermarkets
# 3          SM_/_MAGS_<_2000_M2  Supermarkets small
# 4          SM_/_MAGS_>_2000_M2    Supermarkets big
# 5          REGION_1_IDF_(HMSM)        Paris Region
# 6                     MONOPRIX      MONOPRIX shops
# 7                     FRANPRIX      FRANPRIX shops
#
#                               MARKET_COMMENTS
# 0  including hard discounter and cash & carry
# 1          Hyper > 4.000 m2 (to be confirmed)
# 2
# 3
# 4
# 5
# 6                     city center large shops
# 7                    city center medium shops

# %%
#list of 17 KPI
KPI_U = pd.DataFrame(unique_clean(df_N_ALL,'KPI'), columns =['KPI'])
KPI_U
# Out:
# number of  KPI  unique (non null) values:  17
# <class 'list'>
#                                                 KPI
# 0                                     Ventes_Volume
# 1                                     Ventes_Valeur
# 2                                        Prix_Moyen
# 3                                     Prix_Moyen_UC
# 4                                                DN
# 5                                                DV
# 6                                     VMH_Pondérées
# 7                                      VMH_UC_Pond.
# 8                              CA_Moyen_Hebdo_Pond.
# 9                     Poids_des_Ventes_Volume_Promo
# 10                    Poids_des_Ventes_Valeur_Promo
# 11                              Ventes_Volume_Promo
# 12                              Ventes_Valeur_Promo
# 13                                   Nb_moy_de_Réfs
# 14                             Linéaire_moyen_en_cm
# 15   Part_d'offre_vendante_/_Total_sauces_féculents
# 16  Part_linéaire_vendante_/_Total_sauces_féculents

# %%
#Select Market and KPI
#creation of df_N_prod (1 MARKET * 1 KPI * 1425 PRODUCTS)
MARKET = 'HMSM | PROXI | DRIVE | SDMP' # France
KPI = 'Ventes_Valeur'
MKT_SEGMENT_AND_KPI = (df_N_ALL['KPI'] == KPI) & (df_N_ALL['MARKET'] == MARKET)
df_N_PROD = df_N_ALL[MKT_SEGMENT_AND_KPI]

df_N_PROD.rename(columns={'CAM_AN-1' : KPI + '_2018', 'DERNIER_CAM' : KPI + '_2019'}, inplace=True)

# %%
#Adding N_ in front of each column name 
if not df_N_PROD.columns[0][0:2] == 'N_' :
    for c in df_N_PROD.columns :
        df_N_PROD.rename(columns={c : 'N_' + c}, inplace=True)

# %%
df_N_PROD.columns
# Out:
# Index(['N_MARKET_INITIAL', 'N_FACTS', 'N_NIELSEN_DESCRIPTION', 'N_EMBALLAGE',
#        'N_MARQUE', 'N_GAMME', 'N_FORMAT', 'N_RECETTES', 'N_COMPTE',
#        'N_STD/PROMO', 'N_ITEM', 'N_Ventes_Valeur_2018', 'N_Ventes_Valeur_2019',
#        'N_4_S_28/01/18', 'N_4_S_25/02/18', 'N_4_S_25/03/18', 'N_4_S_22/04/18',
#        'N_4_S_20/05/18', 'N_4_S_17/06/18', 'N_4_S_15/07/18', 'N_4_S_12/08/18',
#        'N_4_S_09/09/18', 'N_4_S_07/10/18', 'N_4_S_04/11/18', 'N_4_S_02/12/18',
#        'N_4_S_30/12/18', 'N_4_S_27/01/19', 'N_4_S_24/02/19', 'N_4_S_24/03/19',
#        'N_4_S_21/04/19', 'N_4_S_19/05/19', 'N_4_S_16/06/19', 'N_4_S_14/07/19',
#        'N_4_S_11/08/19', 'N_4_S_08/09/19', 'N_4_S_06/10/19', 'N_4_S_03/11/19',
#        'N_4_S_01/12/19', 'N_4_S_29/12/19', 'N_EAN13', 'N_MARKET', 'N_KPI',
#        'N_CATEGORY', 'N_ORGANIC', 'N_WEIGHT', 'N_INITIAL_INDEX', 'N_EAN_promo',
#        'N_EAN13_num', 'N_SAME_PRODUCT', 'N_LONG_BRAND', 'N_WEIGHT_num'],
#       dtype='object')

# %%
df_N_PROD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1537 entries, 1538 to 3074
# Data columns (total 51 columns):
# N_MARKET_INITIAL         0 non-null object
# N_FACTS                  1 non-null object
# N_NIELSEN_DESCRIPTION    1536 non-null object
# N_EMBALLAGE              1534 non-null object
# N_MARQUE                 1518 non-null object
# N_GAMME                  1432 non-null object
# N_FORMAT                 1432 non-null object
# N_RECETTES               1432 non-null object
# N_COMPTE                 1432 non-null object
# N_STD/PROMO              1432 non-null object
# N_ITEM                   1432 non-null object
# N_Ventes_Valeur_2018     1536 non-null float64
# N_Ventes_Valeur_2019     1536 non-null float64
# N_4_S_28/01/18           1536 non-null float64
# N_4_S_25/02/18           1536 non-null float64
# N_4_S_25/03/18           1536 non-null float64
# N_4_S_22/04/18           1536 non-null float64
# N_4_S_20/05/18           1536 non-null float64
# N_4_S_17/06/18           1536 non-null float64
# N_4_S_15/07/18           1536 non-null float64
# N_4_S_12/08/18           1536 non-null float64
# N_4_S_09/09/18           1536 non-null float64
# N_4_S_07/10/18           1536 non-null float64
# N_4_S_04/11/18           1536 non-null float64
# N_4_S_02/12/18           1536 non-null float64
# N_4_S_30/12/18           1536 non-null float64
# N_4_S_27/01/19           1536 non-null float64
# N_4_S_24/02/19           1536 non-null float64
# N_4_S_24/03/19           1536 non-null float64
# N_4_S_21/04/19           1536 non-null float64
# N_4_S_19/05/19           1536 non-null float64
# N_4_S_16/06/19           1536 non-null float64
# N_4_S_14/07/19           1536 non-null float64
# N_4_S_11/08/19           1536 non-null float64
# N_4_S_08/09/19           1536 non-null float64
# N_4_S_06/10/19           1536 non-null float64
# N_4_S_03/11/19           1536 non-null float64
# N_4_S_01/12/19           1536 non-null float64
# N_4_S_29/12/19           1536 non-null float64
# N_EAN13                  1537 non-null object
# N_MARKET                 1537 non-null object
# N_KPI                    1537 non-null object
# N_CATEGORY               1536 non-null object
# N_ORGANIC                1536 non-null object
# N_WEIGHT                 1431 non-null object
# N_INITIAL_INDEX          1537 non-null int64
# N_EAN_promo              15 non-null object
# N_EAN13_num              1537 non-null int64
# N_SAME_PRODUCT           1432 non-null object
# N_LONG_BRAND             1460 non-null object
# N_WEIGHT_num             1537 non-null int64
# dtypes: float64(28), int64(3), object(20)
# memory usage: 624.4+ KB

# %%
##############################################@
# 3.2) Column selection for DF_N_PROD

# %%
#Select columns
new_cols = ['N_EAN13', 'N_MARQUE','N_SAME_PRODUCT', 'N_GAMME','N_RECETTES', 'N_ORGANIC', 'N_FORMAT','N_WEIGHT_num', 'N_EMBALLAGE', 
     'N_COMPTE', 'N_STD/PROMO', 'N_Ventes_Valeur_2019', 'N_Ventes_Valeur_2018', 'N_ITEM',
    'N_NIELSEN_DESCRIPTION', 'N_INITIAL_INDEX', 'N_CATEGORY']

df_N_PROD = df_N_PROD.loc[:, new_cols]
#df_N_PROD.reset_index(inplace=True)
df_N_PROD['N_COUNT'] = 1

# %%
df_N_PROD.shape
# Out:
# (1537, 18)

# %%
##############################################@
# 3.3) Remove separation lines from df_N_PROD

# %%
df_N_PROD[['N_EAN13', 'N_EMBALLAGE', 'N_MARQUE', 'N_SAME_PRODUCT', 'N_Ventes_Valeur_2019']].head(50)
# Out:
#           N_EAN13 N_EMBALLAGE N_MARQUE  \
# 0               0         NaN      NaN
# 1               0         NaN      NaN
# 2               0     AUT_EMB      NaN
# 3               0     AUT_EMB   AUT_MQ
# 4   3760052155536     AUT_EMB   AUT_MQ
# 5   8854404005213     AUT_EMB   AUT_MQ
# 6   8858135071028     AUT_EMB   AUT_MQ
# 7   3760052155512     AUT_EMB   AUT_MQ
# 8               0        BRIC      NaN
# 9               0        BRIC      MDD
# 10              0     BTE_FER      NaN
# 11              0     BTE_FER   AUT_MQ
# 12  3416952625159     BTE_FER   AUT_MQ
# 13  3416360008261     BTE_FER   AUT_MQ
# 14              0        DOSE      NaN
# 15              0        DOSE   AUT_MQ
# 16  3302762103218        DOSE   AUT_MQ
# 17  3302762203246        DOSE   AUT_MQ
# 18  3302762203208        DOSE   AUT_MQ
# 19  3302762103133        DOSE   AUT_MQ
# 20  3302762213382        DOSE   AUT_MQ
# 21  3302762203222        DOSE   AUT_MQ
# 22              0     DOY_PAC      NaN
# 23              0     DOY_PAC   AUT_MQ
# 24  9325763000083     DOY_PAC   AUT_MQ
# 25  3760052155505     DOY_PAC   AUT_MQ
# 26  3760070015331     DOY_PAC   AUT_MQ
# 27  3302767151122     DOY_PAC   AUT_MQ
# 28  3302767151139     DOY_PAC   AUT_MQ
# 29  3760070014556     DOY_PAC   AUT_MQ
# 30  3760070014549     DOY_PAC   AUT_MQ
# 31  3760070015324     DOY_PAC   AUT_MQ
# 32  3302767151290     DOY_PAC   AUT_MQ
# 33  3302767151283     DOY_PAC   AUT_MQ
# 34  3760070014525     DOY_PAC   AUT_MQ
# 35  3302767151108     DOY_PAC   AUT_MQ
# 36  3272640001786     DOY_PAC   AUT_MQ
# 37  3760070014518     DOY_PAC   AUT_MQ
# 38  5021047104778     DOY_PAC   AUT_MQ
# 39              0     DOY_PAC      MDD
# 40              0    FLA_PLAS      NaN
# 41              0    FLA_PLAS   AUT_MQ
# 42  5021047104525    FLA_PLAS   AUT_MQ
# 43  8710605030457    FLA_PLAS   AUT_MQ
# 44  6194049100792    FLA_PLAS   AUT_MQ
# 45              0         POT      NaN
# 46              0         POT   AUT_MQ
# 47  3100080000536         POT   AUT_MQ
# 48  5602102238876         POT   AUT_MQ
# 49  3760153840126         POT   AUT_MQ
#
#                                        N_SAME_PRODUCT  N_Ventes_Valeur_2019
# 0                                                 NaN                   NaN
# 1                                                 NaN             5073408.0
# 2                                                 NaN               22078.7
# 3                                                 NaN               22078.7
# 4   AUT_MQ | SCE_CLAS | CITRON_VERT_PIMENT_DOUX | ...                  35.1
# 5   AUT_MQ | SCE_CLAS | CURRY_JAUNE_THAI | AUT_EMB...               14902.2
# 6   AUT_MQ | SCE_CLAS | CURRY_VERT_&_LEGUMES | AUT...                7141.3
# 7        AUT_MQ | SCE_CLAS | YUZU | AUT_EMB | NON_BIO                   0.0
# 8                                                 NaN              139057.0
# 9                                                 NaN              139057.0
# 10                                                NaN               16681.0
# 11                                                NaN               16681.0
# 12  AUT_MQ | SCE_CLAS | CEPES_&_AU_JUS_DE_TRUFFES_...                8020.1
# 13  AUT_MQ | SCE_CLAS | PERIGUEUX_TRUFFEE_A_1% | B...                8660.8
# 14                                                NaN              106768.9
# 15                                                NaN              106768.9
# 16  AUT_MQ | SCE_CLAS | BEURRE_BLANC_&_CITRON_CONF...               52713.1
# 17          AUT_MQ | SCE_CLAS | CEPE | DOSE | NON_BIO               26907.0
# 18  AUT_MQ | SCE_CLAS | CREME_AUX_POIREAUX | DOSE ...               12438.2
# 19  AUT_MQ | SCE_CLAS | LEGUMES_DU_SOLEIL | DOSE |...                2966.2
# 20    AUT_MQ | SCE_CLAS | MOUSSELINE | DOSE | NON_BIO                1105.9
# 21  AUT_MQ | SCE_CLAS | TRUFFE_D'ETE | DOSE | NON_BIO               10638.9
# 22                                                NaN              421351.5
# 23                                                NaN              352512.0
# 24  AUT_MQ | SCE_CLAS | TIKKA_MASALA | DOY_PAC | N...                9767.7
# 25         AUT_MQ | SCE_CLAS | ALGUES | DOY_PAC | BIO                   3.6
# 26  AUT_MQ | SCE_CLAS | ALGUES_AU_SEL_DE_GUERANDE ...                   0.0
# 27  AUT_MQ | SCE_CLAS | ARMORICAINE | DOY_PAC | NO...                   0.0
# 28  AUT_MQ | SCE_CLAS | BEURRE_BLANC_&_CITRON_CONF...                  81.7
# 29  AUT_MQ | SCE_CLAS | BEURRE_BLANC_RICHE_EN_ECHA...               67903.7
# 30  AUT_MQ | SCE_CLAS | BEURRE_CITRON_A_LA_CREME_F...               75244.4
# 31  AUT_MQ | SCE_CLAS | CITRON_VERT_CORIANDRE_AU_S...               30888.2
# 32  AUT_MQ | SCE_CLAS | CREMEE_AU_FOIE_GRAS | DOY_...                   0.0
# 33  AUT_MQ | SCE_CLAS | CREMEE_AUX_MORILLES | DOY_...                 513.0
# 34  AUT_MQ | SCE_CLAS | HOMARD_A_LA_CREME_FRAICHE_...                4778.7
# 35  AUT_MQ | SCE_CLAS | MELANGE_5_BAIES | DOY_PAC ...                   0.0
# 36  AUT_MQ | SCE_CLAS | MOUSS_CHAMP | DOY_PAC | NO...                5820.6
# 37  AUT_MQ | SCE_CLAS | OSEILLE_A_LA_CREME_FRAICHE...               62583.3
# 38  AUT_MQ | SCE_CLAS | PANANG_CURRY | DOY_PAC | N...               94928.0
# 39                                                NaN               68839.2
# 40                                                NaN              343971.3
# 41                                                NaN              343971.3
# 42  AUT_MQ | SCE_CLAS | SWEET_CHILLI | FLA_PLAS | ...              311103.7
# 43  AUT_MQ | SCE_CLAS | CHILLI_SUCREE | FLA_PLAS |...               15058.0
# 44  AUT_MQ | SCE_CLAS | HARISSA_&_PIMENTS | FLA_PL...               17809.9
# 45                                                NaN             4023443.9
# 46                                                NaN             2020188.2
# 47  AUT_MQ | SCE_CLAS | SAUCE_SUPREME_A_LA_TRUFFE_...                5042.5
# 48  AUT_MQ | SCE_CLAS | PIRI_PIRI_A_L'AIL | POT | ...               21977.8
# 49  AUT_MQ | SCE_CLAS | PISTOU_BASILIC | POT | NON...               15105.5

# %%
#definition of rows to keep

#EAN13 != 0
#or
#brand contains 'MDD' 
#or
#brand contains 'MDD 1 PRX'

row_to_keep = (df_N_PROD['N_EAN13'] != '0') | (df_N_PROD['N_MARQUE'] == 'MDD') | (df_N_PROD['N_MARQUE'] == 'MDD 1 PRX')

# %%
row_to_keep.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8    False
# 9     True
# dtype: bool

# %%
#creation of data frame with no seperators
df_N_PROD = df_N_PROD[row_to_keep]
print(df_N_PROD.shape)
df_N_PROD
# Out:
# (1441, 18)
#             N_EAN13         N_MARQUE  \
# 4     3760052155536           AUT_MQ
# 5     8854404005213           AUT_MQ
# 6     8858135071028           AUT_MQ
# 7     3760052155512           AUT_MQ
# 9                 0              MDD
# ...             ...              ...
# 1530  3038359002823          PANZANI
# 1531  3038359008498          PANZANI
# 1532  3038359005657          PANZANI
# 1534  3038359001413            ZAKIA
# 1536  3021690021851  ZAPETTI_BUITONI
#
#                                          N_SAME_PRODUCT   N_GAMME  \
# 4     AUT_MQ | SCE_CLAS | CITRON_VERT_PIMENT_DOUX | ...  SCE_CLAS
# 5     AUT_MQ | SCE_CLAS | CURRY_JAUNE_THAI | AUT_EMB...  SCE_CLAS
# 6     AUT_MQ | SCE_CLAS | CURRY_VERT_&_LEGUMES | AUT...  SCE_CLAS
# 7          AUT_MQ | SCE_CLAS | YUZU | AUT_EMB | NON_BIO  SCE_CLAS
# 9                                                   NaN       NaN
# ...                                                 ...       ...
# 1530      PANZANI | LEGUMES | PT_LEGUME | TUB | NON_BIO   LEGUMES
# 1531  PANZANI | LEGUMES | TOM_CUI_A_L'ORIGAN | TUB |...   LEGUMES
# 1532       PANZANI | PESTO | PESTO_VERD | TUB | NON_BIO     PESTO
# 1534   ZAKIA | LEGUMES | TOMATE_PIMENTE | TUB | NON_BIO   LEGUMES
# 1536  ZAPETTI_BUITONI | LEGUMES | NATURE | TUB | NON...   LEGUMES
#
#                    N_RECETTES  N_ORGANIC N_FORMAT  N_WEIGHT_num N_EMBALLAGE  \
# 4     CITRON_VERT_PIMENT_DOUX    NON_BIO       PF           100     AUT_EMB
# 5            CURRY_JAUNE_THAI    NON_BIO       PF           300     AUT_EMB
# 6        CURRY_VERT_&_LEGUMES    NON_BIO       PF           300     AUT_EMB
# 7                        YUZU    NON_BIO       PF           100     AUT_EMB
# 9                         NaN  separator      NaN             0        BRIC
# ...                       ...        ...      ...           ...         ...
# 1530                PT_LEGUME    NON_BIO       PF           180         TUB
# 1531       TOM_CUI_A_L'ORIGAN    NON_BIO       PF           180         TUB
# 1532               PESTO_VERD    NON_BIO       PF           160         TUB
# 1534           TOMATE_PIMENTE    NON_BIO       PF           180         TUB
# 1536                   NATURE    NON_BIO       PF           150         TUB
#
#      N_COMPTE N_STD/PROMO  N_Ventes_Valeur_2019  N_Ventes_Valeur_2018  \
# 4         1CT         STD                  35.1                1563.3
# 5         1CT         STD               14902.2               11908.0
# 6         1CT         STD                7141.3                   0.0
# 7         1CT         STD                   0.0                1010.2
# 9         NaN         NaN              139057.0                   0.0
# ...       ...         ...                   ...                   ...
# 1530      3CT         STD                   0.0                   0.0
# 1531      1CT         STD              103313.2               11878.0
# 1532      1CT         STD              453348.9              425910.7
# 1534      1CT         STD              182191.4              110804.6
# 1536      1CT         STD                   0.0                   0.8
#
#              N_ITEM                              N_NIELSEN_DESCRIPTION  \
# 4     3760052155536  AUT_EMB_AUT_FAB_AUT_MQ_SCE_CLAS_PF_CITRON_VERT...
# 5     8854404005213  AUT_SCE_AUT_EMB_AUT_FAB_AUT_MQ_SCE_CLAS_PF_CUR...
# 6     8858135071028  SCE_AUT_EMB_AUT_FAB_AUT_MQ_SCE_CLAS_PF_CURRY_V...
# 7     3760052155512  AUT_SCE_AUT_EMB_AUT_FAB_AUT_MQ_SCE_CLAS_PF_YUZ...
# 9               NaN                                   AUT_SCE_BRIC_MDD
# ...             ...                                                ...
# 1530  3038359002823  POUR_FECULENTS_TUB_PANZANI_SA_PANZANI_LEGUMES_...
# 1531  3038359008498  TUB_PANZANI_SA_PANZANI_LEGUMES_PF_TOM_CUI_A_L'...
# 1532  3038359005657  POUR_FECULENTS_TUB_PANZANI_SA_PANZANI_PESTO_PF...
# 1534  3038359001413  POUR_FECULENTS_TUB_AUT_FAB_ZAKIA_LEGUMES_PF_TO...
# 1536  3021690021851  POUR_FECULENTS_TUB_ZAPETTI_ZAPETTI_BUITONI_LEG...
#
#       N_INITIAL_INDEX             N_CATEGORY  N_COUNT
# 4                1542                AUT_SCE        1
# 5                1543                AUT_SCE        1
# 6                1544                AUT_SCE        1
# 7                1545                AUT_SCE        1
# 9                1547                AUT_SCE        1
# ...               ...                    ...      ...
# 1530             3068  SAUCES_POUR_FECULENTS        1
# 1531             3069  SAUCES_POUR_FECULENTS        1
# 1532             3070  SAUCES_POUR_FECULENTS        1
# 1534             3072  SAUCES_POUR_FECULENTS        1
# 1536             3074  SAUCES_POUR_FECULENTS        1
#
# [1441 rows x 18 columns]

# %%
#reset index of df_N_prod with final rows
df_N_PROD = df_N_PROD[row_to_keep].reset_index(inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# Number of rows per brand
df_N_PROD[[ 'N_MARQUE','N_COUNT','N_Ventes_Valeur_2019','N_Ventes_Valeur_2018']].groupby(by='N_MARQUE').sum().sort_values(by='N_DERNIER CAM', ascending=False)
# Out:
#                        N_COUNT  N_DERNIER CAM  N_CAM AN-1
# N_MARQUE
# MDD                          9     33919062.4  32157699.9
# PANZANI                    179     28699809.7  30472967.7
# BARILLA                     79      9563414.9   8662021.6
# ZAPETTI BUITONI             95      3751200.1   3787721.1
# HEINZ                       61      3039459.2   3174146.3
# SACLA                       98      1585406.4   1709201.0
# MDD 1 PRX                    2      1048173.1   1154908.9
# AUT MQ                     667       960493.9    945941.8
# JARDIN BIO                  33       903909.8    789980.8
# MQ FAB 1 PRX                15       547005.1    511791.4
# FLORELLI                    38       208851.1    232246.0
# LUCIEN GEORGELIN            22       171582.3     88535.6
# ZAKIA                        2       143397.8    134891.7
# RUMMO                        6       109080.5     91891.5
# CIRIO                       10        82329.9    107656.2
# ITALIANS DO IT BETTER       19        71122.7     51653.2
# OLD EL PASO                  2        34006.7     41380.7
# RIVOIRE & CARRET             7        33816.2     34239.5
# LOUIS MARTIN                21        23678.1     23709.8
# DE CECCO                    14        22955.3     25359.2
# VICTORIA                     3        12343.8      8165.4
# SUZY WAN                     4        10647.6     14045.9
# CASERTA                      8        10381.8      9569.2
# MUTTI                       12         9156.3     13269.6
# UNC BENS                     1         8629.8         0.0
# BJORG                        3         7260.8     13535.3
# POLLI                       13         5801.0      2476.3
# KNORR                        1         4775.0      5110.0
# LE CABANON                  10         3505.2      6622.9
# BUITONI                      8           28.2        10.6
# SOLEILLANS                   1            0.0         1.5

# %%
#check total of sales value = 343 809 410,40 €
#CHECK THAT N_PROD total sales = 84 991 284,70 €

df_N_PROD['N_Ventes_Valeur_2019'].sum()#== 343809410.40
# Out:
# 1270582955.1

# %%
#################################################
# 4) MERGING N_PROD AND O_PROD INTO M_PROD      #
#################################################

# %%
#################################################
# 4.1) Merge of the two databases

# %%
df_M_PROD = df_N_PROD.merge(df_O_PROD, left_on='N_EAN13', right_on='O_EAN13', how='left')
df_M_PROD.shape
# Out:
# (1537, 91)

# %%
df_M_PROD.columns
# Out:
# Index(['N_MARKET_INITIAL', 'N_FACTS', 'N_NIELSEN_DESCRIPTION', 'N_EMBALLAGE',
#        'N_MARQUE', 'N_GAMME', 'N_FORMAT', 'N_RECETTES', 'N_COMPTE',
#        'N_STD/PROMO', 'N_ITEM', 'N_Ventes_Valeur_2018', 'N_Ventes_Valeur_2019',
#        'N_4 S 28/01/18', 'N_4 S 25/02/18', 'N_4 S 25/03/18', 'N_4 S 22/04/18',
#        'N_4 S 20/05/18', 'N_4 S 17/06/18', 'N_4 S 15/07/18', 'N_4 S 12/08/18',
#        'N_4 S 09/09/18', 'N_4 S 07/10/18', 'N_4 S 04/11/18', 'N_4 S 02/12/18',
#        'N_4 S 30/12/18', 'N_4 S 27/01/19', 'N_4 S 24/02/19', 'N_4 S 24/03/19',
#        'N_4 S 21/04/19', 'N_4 S 19/05/19', 'N_4 S 16/06/19', 'N_4 S 14/07/19',
#        'N_4 S 11/08/19', 'N_4 S 08/09/19', 'N_4 S 06/10/19', 'N_4 S 03/11/19',
#        'N_4 S 01/12/19', 'N_4 S 29/12/19', 'N_EAN13', 'N_MARKET', 'N_KPI',
#        'N_CATEGORY', 'N_ORGANIC', 'N_WEIGHT', 'N_INITIAL_INDEX', 'N_EAN_promo',
#        'N_EAN13_num', 'N_SAME_PRODUCT', 'N_LONG_BRAND', 'N_WEIGHT_num',
#        'O_EAN13', 'O_categories', 'O_ingredients', 'O_nutriments',
#        'O_product_name', 'O_manufacturing_places', 'O_category_properties',
#        'O_ingredients_text', 'O_product_name_fr',
#        'O_interface_version_modified', 'O_ingredients_n', 'O_pnns_groups_1',
#        'O_pnns_groups_2', 'O_cities_tags', 'O_compared_to_category',
#        'O_countries_hierarchy', 'O_salt_content', 'O_oil_content',
#        'O_serving_quantity', 'O_serving_size', 'O_max_salt_content',
#        'O_min_salt_content', 'O_max_oil_content', 'O_min_oil_content',
#        'O_oil_type', 'O_energy_100g', 'O_energy_kcal_100g',
#        'O_saturated_fat_100g', 'O_fat_100g', 'O_carbohydrates_100g',
#        'O_sugars_100g',
#        'O_fruits_vegetables_nuts_estimate_from_ingredients_100g',
#        'O_proteins_100g', 'O_sodium_100g', 'O_salt_100g',
#        'O_nutrition_score_fr_100g', 'O_fiber_100g', 'O_nova_group_100g',
#        'O_COUNT', 'O_date_modified'],
#       dtype='object')

# %%
df_M_PROD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1443 entries, 0 to 1442
# Data columns (total 58 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   N_EAN13                                                  1443 non-null   object
#  1   N_MARQUE                                                 1443 non-null   object
#  2   N_SAME_PRODUCT                                           1432 non-null   object
#  3   N_GAMME                                                  1432 non-null   object
#  4   N_RECETTES                                               1432 non-null   object
#  5   N_ORGANIC                                                1443 non-null   object
#  6   N_FORMAT                                                 1432 non-null   object
#  7   N_WEIGHT_num                                             1443 non-null   int64
#  8   N_EMBALLAGE                                              1443 non-null   object
#  9   N_COMPTE                                                 1432 non-null   object
#  10  N_STD/PROMO                                              1432 non-null   object
#  11  N_DERNIER CAM                                            1443 non-null   float64
#  12  N_CAM AN-1                                               1443 non-null   float64
#  13  N_ITEM                                                   1432 non-null   object
#  14  N_NIELSEN_DESCRIPTION                                    1443 non-null   object
#  15  N_INITIAL_INDEX                                          1443 non-null   int64
#  16  N_CATEGORY                                               1443 non-null   object
#  17  N_COUNT                                                  1443 non-null   int64
#  18  O_EAN13                                                  1103 non-null   object
#  19  O_categories                                             666 non-null    object
#  20  O_ingredients                                            978 non-null    object
#  21  O_nutriments                                             1103 non-null   object
#  22  O_product_name                                           1093 non-null   object
#  23  O_manufacturing_places                                   213 non-null    object
#  24  O_category_properties                                    1099 non-null   object
#  25  O_ingredients_text                                       646 non-null    object
#  26  O_product_name_fr                                        1066 non-null   object
#  27  O_interface_version_modified                             1101 non-null   object
#  28  O_ingredients_n                                          646 non-null    float64
#  29  O_pnns_groups_1                                          1103 non-null   object
#  30  O_pnns_groups_2                                          1103 non-null   object
#  31  O_cities_tags                                            588 non-null    object
#  32  O_compared_to_category                                   657 non-null    object
#  33  O_countries_hierarchy                                    1103 non-null   object
#  34  O_salt_content                                           978 non-null    object
#  35  O_oil_content                                            978 non-null    object
#  36  O_serving_quantity                                       92 non-null     float64
#  37  O_serving_size                                           92 non-null     object
#  38  O_max_salt_content                                       1103 non-null   float64
#  39  O_min_salt_content                                       1103 non-null   float64
#  40  O_max_oil_content                                        1103 non-null   float64
#  41  O_min_oil_content                                        1103 non-null   float64
#  42  O_oil_type                                               335 non-null    object
#  43  O_energy_100g                                            1060 non-null   float64
#  44  O_energy_kcal_100g                                       910 non-null    float64
#  45  O_saturated_fat_100g                                     1052 non-null   float64
#  46  O_fat_100g                                               1056 non-null   float64
#  47  O_carbohydrates_100g                                     1055 non-null   float64
#  48  O_sugars_100g                                            1052 non-null   float64
#  49  O_fruits_vegetables_nuts_estimate_from_ingredients_100g  645 non-null    float64
#  50  O_proteins_100g                                          1060 non-null   float64
#  51  O_sodium_100g                                            1050 non-null   float64
#  52  O_salt_100g                                              1050 non-null   float64
#  53  O_nutrition_score_fr_100g                                638 non-null    float64
#  54  O_fiber_100g                                             393 non-null    float64
#  55  O_nova_group_100g                                        527 non-null    float64
#  56  O_COUNT                                                  1103 non-null   float64
#  57  O_date_modified                                          1103 non-null   object
# dtypes: float64(22), int64(3), object(33)
# memory usage: 665.1+ KB

# %%
#check total of sales value = 343 809 410,40 €
#check total of sales volume = 84.991.284,70
df_M_PROD['N_Ventes_Valeur_2019'].sum()
# Out:
# 1270582955.1

# %%
#------------------------------------------------
#SAVE M-PROD
df_M_PROD.to_csv('M_MERGE/output_data/M_PROD.csv')

# %%
df_M_PROD.tail(10)
# Out:
#             N_EAN13         N_MARQUE  \
# 1433  3038352871303          PANZANI
# 1434  3038359002335          PANZANI
# 1435  3038359004544          PANZANI
# 1436  3038359008603          PANZANI
# 1437  3038359004551          PANZANI
# 1438  3038359002823          PANZANI
# 1439  3038359008498          PANZANI
# 1440  3038359005657          PANZANI
# 1441  3038359001413            ZAKIA
# 1442  3021690021851  ZAPETTI BUITONI
#
#                                          N_SAME_PRODUCT  N_GAMME  \
# 1433     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1434     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1435     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1436     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1437     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1438     PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO  LEGUMES
# 1439  PANZANI + LEGUMES + TOM CUI A L'ORIGAN + TUB +...  LEGUMES
# 1440      PANZANI + PESTO + PESTO VERD + TUB +  NON BIO    PESTO
# 1441  ZAKIA + LEGUMES + TOMATE PIMENTE + TUB +  NON BIO  LEGUMES
# 1442  ZAPETTI BUITONI + LEGUMES + NATURE + TUB +  NO...  LEGUMES
#
#               N_RECETTES N_ORGANIC N_FORMAT  N_WEIGHT_num N_EMBALLAGE  \
# 1433           PT LEGUME   NON BIO       PF           180         TUB
# 1434           PT LEGUME   NON BIO       PF           180         TUB
# 1435           PT LEGUME   NON BIO       PF           180         TUB
# 1436           PT LEGUME   NON BIO       PF           220         TUB
# 1437           PT LEGUME   NON BIO       PF           180         TUB
# 1438           PT LEGUME   NON BIO       PF           180         TUB
# 1439  TOM CUI A L'ORIGAN   NON BIO       PF           180         TUB
# 1440          PESTO VERD   NON BIO       PF           160         TUB
# 1441      TOMATE PIMENTE   NON BIO       PF           180         TUB
# 1442              NATURE   NON BIO       PF           150         TUB
#
#      N_COMPTE  ... O_sugars_100g  \
# 1433      1CT  ...           8.1
# 1434      1CT  ...           8.1
# 1435      1CT  ...           9.1
# 1436      1CT  ...           9.1
# 1437      3CT  ...           NaN
# 1438      3CT  ...           8.1
# 1439      1CT  ...          10.0
# 1440      1CT  ...           6.1
# 1441      1CT  ...           8.1
# 1442      1CT  ...           7.1
#
#       O_fruits_vegetables_nuts_estimate_from_ingredients_100g  \
# 1433                                          50.321429
# 1434                                          50.000000
# 1435                                          50.000000
# 1436                                          49.750000
# 1437                                                NaN
# 1438                                                NaN
# 1439                                          49.000000
# 1440                                           0.000000
# 1441                                          50.050000
# 1442                                          87.000000
#
#       O_proteins_100g O_sodium_100g O_salt_100g  O_nutrition_score_fr_100g  \
# 1433              2.7       1.12000      2.8000                        9.0
# 1434              2.7       1.12000      2.8000                        9.0
# 1435              2.9       1.16000      2.9000                       11.0
# 1436              2.9       1.16000      2.9000                       11.0
# 1437              NaN           NaN         NaN                        NaN
# 1438              2.7       1.12000      2.8000                        NaN
# 1439              2.9       1.16000      2.9000                       11.0
# 1440              4.4       1.28000      3.2000                       13.0
# 1441              2.7       1.12000      2.8000                        NaN
# 1442              1.7       0.56896      1.4224                        1.0
#
#      O_fiber_100g  O_nova_group_100g O_COUNT O_date_modified
# 1433          2.7                4.0     1.0        20120622
# 1434          2.7                4.0     1.0        20130323
# 1435          1.7                4.0     1.0        20150316
# 1436          1.7                4.0     1.0        20150316
# 1437          NaN                NaN     1.0        20150316
# 1438          NaN                NaN     1.0        20150316
# 1439          1.7                4.0     1.0        20150316
# 1440          2.5                4.0     1.0        20150316
# 1441          2.7                4.0     1.0        20150316
# 1442          1.9                4.0     1.0        20120622
#
# [10 rows x 58 columns]

# %%
############################################
# 4.2) Analysis of missing N_EAN13 in O_PROD

# %%
#--------------------------------------------
#     CREATION OF df_M_SAME_PROD
#--------------------------------------------
# columns kept must be sumable

df_M_SAME_PROD = df_M_PROD[['N_SAME_PRODUCT', 'N_COUNT', 'O_COUNT', 'N_DERNIER CAM', 'N_CAM AN-1']].groupby(['N_SAME_PRODUCT']).sum().sort_values(by='N_DERNIER CAM', ascending=False)
df_M_SAME_PROD['MISSING_COUNT'] = df_M_SAME_PROD['N_COUNT'].astype(int) - df_M_SAME_PROD['O_COUNT'].astype(int)
df_M_SAME_PROD= df_M_SAME_PROD[['N_COUNT', 'O_COUNT','MISSING_COUNT', 'N_DERNIER CAM', 'N_CAM AN-1']]
df_M_SAME_PROD
# Out:
#                                                     N_COUNT  O_COUNT  \
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO          17     10.0
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...       26     19.0
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO            6      6.0
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO          11     10.0
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...       11      7.0
# ...                                                     ...      ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO        1      0.0
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO           1      0.0
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO           1      0.0
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO        1      0.0
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...        1      0.0
#
#                                                     MISSING_COUNT  \
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO                 7
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...              7
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO                  0
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO                 1
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...              4
# ...                                                           ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO              1
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO                 1
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO                 1
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO              1
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...              1
#
#                                                     N_DERNIER CAM  N_CAM AN-1
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO         4905419.6   4747571.5
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...      4899534.7   8800759.4
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO          3071093.9   3081322.4
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO         2670954.1   2632010.4
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...      2418763.9   2392954.5
# ...                                                           ...         ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO            0.0         0.0
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO               0.0         0.0
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO               0.0         1.2
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO            0.0         1.0
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...            0.0         0.1
#
# [771 rows x 5 columns]

# %%
df_M_SAME_PROD.shape
# Out:
# (771, 5)

# %%
df_M_SAME_PROD.info
# Out:
# <bound method DataFrame.info of                                                     N_COUNT  O_COUNT  \
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO          17     10.0
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...       26     19.0
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO            6      6.0
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO          11     10.0
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...       11      7.0
# ...                                                     ...      ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO        1      0.0
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO           1      0.0
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO           1      0.0
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO        1      0.0
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...        1      0.0
#
#                                                     MISSING_COUNT  \
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO                 7
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...              7
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO                  0
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO                 1
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...              4
# ...                                                           ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO              1
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO                 1
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO                 1
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO              1
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...              1
#
#                                                     N_DERNIER CAM  N_CAM AN-1
# N_SAME_PRODUCT
# PANZANI + LEGUMES + PROVENCALE + POT +  NON BIO         4905419.6   4747571.5
# PANZANI + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...      4899534.7   8800759.4
# PANZANI + LEGUMES + PT LEGUME + TUB +  NON BIO          3071093.9   3081322.4
# PANZANI + LEGUMES + TOMATE CUI + POT +  NON BIO         2670954.1   2632010.4
# ZAPETTI BUITONI + BOLO CLASSIQUE + ITALIEN + BT...      2418763.9   2392954.5
# ...                                                           ...         ...
# PANZANI + LEGUMES + FRAICHEUR + BTE FER +  NON BIO            0.0         0.0
# PANZANI + LEGUMES + LEGUME + BTE FER +  NON BIO               0.0         0.0
# PANZANI + LEGUMES + REC DU SUD + POT +  NON BIO               0.0         1.2
# AUT MQ + LEGUMES + TOMATE CUI + BTE FER +  NON BIO            0.0         1.0
# ZAPETTI BUITONI + PESTO + PESTO VERD + DOSE +  ...            0.0         0.1
#
# [771 rows x 5 columns]>

# %%
#SAVE M_SAME_PROD
df_M_SAME_PROD.to_csv('M_MERGE/output_data/M_SAME_PROD.csv')

# %%
#-----------------------------------------------------------
#           CREATION OF df_M_SAME_PROD_MISSING 
#          (totally missing in OPEN FOOD FACTS)
#   !!!!! ATTENTION TO 'AUT MQ' (other brands)  !!!!!!!!!!
#-----------------------------------------------------------

df_M_SAME_PROD_MISSING = df_M_SAME_PROD[df_M_SAME_PROD['O_COUNT'] == 0]
df_M_SAME_PROD_MISSING.shape
# Out:
# (97, 5)

# %%
#SAVE M_SAME_PROD_MISSING
df_M_SAME_PROD_MISSING.to_csv('M_MERGE/output_data/M_SAME_PROD_MISSING.csv')

# %%
print('sales of same_products with no match in OPENFF:', round(df_M_SAME_PROD_MISSING['N_DERNIER CAM'].sum(),0),'€')
print('number of same_products with no match in OPENFF:', round(df_M_SAME_PROD_MISSING['N_DERNIER CAM'].count()))
print('max sales of same_product with no match in OPENFF:', round(df_M_SAME_PROD_MISSING['N_DERNIER CAM'].max(),0),'€')

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# resultat trompeur car pour les marques dans 'AUT MQ' la correspondance n'est pas bonne
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# sales of same_products with no match in OPENFF: 14780.0 €
# number of same_products with no match in OPENFF: 97
# max sales of same_product with no match in OPENFF: 4775.0 €

# %%
df_M_SAME_PROD_MISSING.index
# Out:
# Index(['KNORR, LEGUMES, LEGUME, BTE FER, ',
#        'MQ FAB 1 PRX, BOLO CLASSIQUE, BOLOG VDE, POT, ',
#        'ITALIANS DO IT BETTER, AUTRE GAMME, RAGU DE VIANDE, POT, ',
#        'AUT MQ, SCE CLAS, CURRY INDIENNE TIKKA MASALA, POT, ',
#        'AUT MQ, LEGUMES, AIL, POT, ',
#        'MQ FAB 1 PRX, SCE CLAS, PESTO CALABRESE, POT, ',
#        'AUT MQ, SCE CLAS, HOMARD A LA CREME FRAICHE & AU, DOY PAC, ',
#        'CASERTA, BOLO CLASSIQUE, BOLOGNAISE, POT, ',
#        'AUT MQ, SCE CLAS, CURRY INDIENNE CURRY DOUX, POT, ',
#        'AUT MQ, SCE CLAS, SAUCE SUPREME A LA TRUFFE DU P, POT, ',
#        'AUT MQ, SCE CLAS, BRUSCHETTA OLIVES NOIRES, POT, ',
#        'AUT MQ, AUTRE GAMME, PIQUANTE CALABRESE, POT, ',
#        'VICTORIA, LEGUMES, NAPOLITAIN, POT, ', 'AUT MQ, SCE CLAS, CEPE, POT, ',
#        'AUT MQ, LEGUMES, SPAGHETTI, POT, ', 'AUT MQ, LEGUMES, CURRY, POT, ',
#        'LOUIS MARTIN, BOLO CLASSIQUE, ITALIEN, BTE FER, ',
#        'AUT MQ, LEGUMES, SAUCE CARI, POT, ',
#        'LOUIS MARTIN, LEGUMES, CHAMPIGNON, POT, ',
#        'AUT MQ, AUTRE GAMME, ENCRE SEIC, POT, ',
#        'PANZANI, LEGUMES, BASILIC CISELE, POT, ',
#        'BUITONI, BOLO CLASSIQUE, ITALIEN, BTE FER, ',
#        'DE CECCO, LEGUMES, VERDURE, POT, ',
#        'AUT MQ, LEGUMES, PIMENT D'ESPELETTE, POT, ',
#        'AUT MQ, LEGUMES, LANGUEDOC, POT, ', 'AUT MQ, LEGUMES, BRASERO, POT, ',
#        'AUT MQ, LEGUMES, GINGER TONIC, POT, ',
#        'AUT MQ, LEGUMES, PROVENCALE, BTE FER, ',
#        'AUT MQ, LEGUMES, RIVIERA, POT, ',
#        'AUT MQ, SCE CLAS, BEURRE BLANC & CITRON CONFIT, DOY PAC, ',
#        'AUT MQ, SCE CLAS, BECHAMEL CHAMPIGNONS & PARMESA, POT, ',
#        'BUITONI, LEGUMES, NATURE, BTE FER, ',
#        'ZAPETTI BUITONI, BOLO CLASSIQUE, BOLOGNAISE AU BOEUF RISSOLE, POT, ',
#        'AUT MQ, LEGUMES, CHAMP PORCI, POT, ',
#        'AUT MQ, SCE CLAS, CITRON VERT PIMENT DOUX, AUT EMB, ',
#        'AUT MQ, PESTO, PESTO RGE, TUB, ', 'AUT MQ, LEGUMES, MELANZANE, POT, ',
#        'AUT MQ, AUTRE GAMME, GIROLLE V NOIX, BTE FER, ',
#        'AUT MQ, LEGUMES, TOM OIGNON, POT, ',
#        'AUT MQ, SCE CLAS, ALGUES, DOY PAC, ',
#        'AUT MQ, LEGUMES, BASILIC, DOY PAC, ',
#        'VICTORIA, BOLO CLASSIQUE, BOLOGNAISE, POT, ',
#        'AUT MQ, BIO, AUBERGINE CHEVRE, DOY PAC, ',
#        'BARILLA, PESTO, TOM SECHE, POT, ',
#        'HEINZ, LEGUMES, PARMESAN, DOY PAC, ',
#        'HEINZ, LEGUMES, TOMATE CUI, BRIC, ',
#        'BARILLA, LEGUMES, SICILIAN, POT, ',
#        'HEINZ, LEGUMES, TOMATE CUITE HUILE OLIVE, BRIC, ',
#        'BARILLA, PESTO, PEST OIG DX, POT, ',
#        'BARILLA, LEGUMES, TOMATES CERISE ARRABBIATA, POT, ',
#        'AUT MQ, AUTRE GAMME, ORANG, POT, ',
#        'AUT MQ, SCE POISSON, VONGOLE, POT, ',
#        'AUT MQ, SCE POISSON, MOULE, POT, ',
#        'AUT MQ, SCE POISSON, CLOVISSE, POT, ',
#        'AUT MQ, SCE POISSON, ANCHOIS, POT, ',
#        'AUT MQ, SCE CLAS, YUZU, AUT EMB, ',
#        'AUT MQ, LEGUMES, GRAN PAD PECO CHEESE, POT, ',
#        'HEINZ, LEGUMES, BASILIC, BRIC, ',
#        'AUT MQ, AUT VIANDE, POITRINE DE PORC, POT, ',
#        'AUT MQ, AUT VIANDE, TOSCANA, POT, ',
#        'ZAPETTI BUITONI, LEGUMES, PROVENC LANGUE, POT, ',
#        'AUT MQ, AUTRE GAMME, CALABRAIS, FLA PLAS, ',
#        'AUT MQ, AUT VIANDE, JAMB SAUCI, POT, ',
#        'CASERTA, LEGUMES, BASILIC, BTE FER, ',
#        'ZAPETTI BUITONI, LEGUMES, HERB PROV, POT, ',
#        'BUITONI, LEGUMES, PARMESAN, POT, ',
#        'BUITONI, LEGUMES, NAPOLITAIN, POT, ',
#        'BUITONI, LEGUMES, BASILIC, POT, ',
#        'BUITONI, BOLO CLASSIQUE, BOLOGNAISE, POT, ',
#        'ZAPETTI BUITONI, BOLO CLASSIQUE, BOLOGNAISE BOEUF RISSOLE, POT, ',
#        'ZAPETTI BUITONI, BOLO ORIGINALE, BOLO TEX MEX, POT, ',
#        'AUT MQ, LEGUMES, TOMATE CUI, BTE FER, ',
#        'AUT MQ, SCE CLAS, ALGUES AU SEL DE GUERANDE, DOY PAC, ',
#        'AUT MQ, SCE CLAS, AGLIO & OLIO & PEPERONCINO CAL, POT, ',
#        'AUT MQ, LEGUMES, ANDALOUSE, POT, ',
#        'PANZANI, LEGUMES, FRAICHEUR, BTE FER, ',
#        'AUT MQ, LEGUMES, AUBER OLIV OIL, POT, ',
#        'PANZANI, LEGUMES, LEGUME, BTE FER, ',
#        'PANZANI, LEGUMES, REC DU SUD, POT, ', 'AUT MQ, LEGUMES, BOLET, POT, ',
#        'PANZANI, SCE POISSON, TOMATES CUISINES THON, POT, ',
#        'POLLI, A CUISINER, RISOTTO TOMATES & BASILIC, POT, ',
#        'AUT MQ, LEGUMES, POMODORO, POT, ',
#        'PANZANI, BOLO ORIGINALE, BOLOG BARBEC, POT, ',
#        'AUT MQ, LEGUMES, *, POT, ', 'AUT MQ, SCE CLAS, PIZZA, POT, ',
#        'LE CABANON, LEGUMES, CHAMPIGNON, POT, ',
#        'SACLA, LEGUMES, TOMATES BASILIC, POT, ',
#        'AUT MQ, SCE CLAS, ONCTUEUSE AU RIZ, POT, ',
#        'AUT MQ, SCE CLAS, NAPOLITAIN, POT, ',
#        'AUT MQ, SCE CLAS, MELANGE 5 BAIES, DOY PAC, ',
#        'SACLA, LEGUMES, TOM C PARM, POT, ',
#        'AUT MQ, SCE CLAS, KASHMIRI MILD KORMA, POT, ',
#        'AUT MQ, SCE CLAS, JAUNTY JALFREZI PASTE, POT, ',
#        'AUT MQ, SCE CLAS, CREMEE AU FOIE GRAS, DOY PAC, ',
#        'AUT MQ, BOLO ORIGINALE, BOLOGNAISE VOLAILLE, POT, ',
#        'ZAPETTI BUITONI, PESTO, PESTO VERD, DOSE, '],
#       dtype='object', name='N_SAME_PRODUCT')

# %%
df_M_SAME_PROD_MISSING.sort_values(by='N_DERNIER CAM',ascending=False).head(15)
# Out:
#                                                     N_COUNT  O_COUNT  \
# N_SAME_PRODUCT
# KNORR + LEGUMES + LEGUME + BTE FER +  NON BIO             1      0.0
# MQ FAB 1 PRX + BOLO CLASSIQUE + BOLOG VDE + POT...        1      0.0
# ITALIANS DO IT BETTER + AUTRE GAMME + RAGU DE V...        1      0.0
# AUT MQ + SCE CLAS + CURRY INDIENNE TIKKA MASALA...        1      0.0
# AUT MQ + LEGUMES + AIL + POT +  NON BIO                   1      0.0
# MQ FAB 1 PRX + SCE CLAS + PESTO CALABRESE + POT...        1      0.0
# AUT MQ + SCE CLAS + HOMARD A LA CREME FRAICHE &...        1      0.0
# CASERTA + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...        1      0.0
# AUT MQ + SCE CLAS + CURRY INDIENNE CURRY DOUX +...        1      0.0
# AUT MQ + SCE CLAS + SAUCE SUPREME A LA TRUFFE D...        1      0.0
# AUT MQ + SCE CLAS + BRUSCHETTA OLIVES NOIRES + ...        1      0.0
# AUT MQ + AUTRE GAMME + PIQUANTE CALABRESE + POT...        1      0.0
# VICTORIA + LEGUMES + NAPOLITAIN + POT +  NON BIO          1      0.0
# AUT MQ + SCE CLAS + CEPE + POT +  NON BIO                 1      0.0
# AUT MQ + LEGUMES + SPAGHETTI + POT +  NON BIO             1      0.0
#
#                                                     MISSING_COUNT  \
# N_SAME_PRODUCT
# KNORR + LEGUMES + LEGUME + BTE FER +  NON BIO                   1
# MQ FAB 1 PRX + BOLO CLASSIQUE + BOLOG VDE + POT...              1
# ITALIANS DO IT BETTER + AUTRE GAMME + RAGU DE V...              1
# AUT MQ + SCE CLAS + CURRY INDIENNE TIKKA MASALA...              1
# AUT MQ + LEGUMES + AIL + POT +  NON BIO                         1
# MQ FAB 1 PRX + SCE CLAS + PESTO CALABRESE + POT...              1
# AUT MQ + SCE CLAS + HOMARD A LA CREME FRAICHE &...              1
# CASERTA + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...              1
# AUT MQ + SCE CLAS + CURRY INDIENNE CURRY DOUX +...              1
# AUT MQ + SCE CLAS + SAUCE SUPREME A LA TRUFFE D...              1
# AUT MQ + SCE CLAS + BRUSCHETTA OLIVES NOIRES + ...              1
# AUT MQ + AUTRE GAMME + PIQUANTE CALABRESE + POT...              1
# VICTORIA + LEGUMES + NAPOLITAIN + POT +  NON BIO                1
# AUT MQ + SCE CLAS + CEPE + POT +  NON BIO                       1
# AUT MQ + LEGUMES + SPAGHETTI + POT +  NON BIO                   1
#
#                                                     N_DERNIER CAM  N_CAM AN-1
# N_SAME_PRODUCT
# KNORR + LEGUMES + LEGUME + BTE FER +  NON BIO              4775.0      5110.0
# MQ FAB 1 PRX + BOLO CLASSIQUE + BOLOG VDE + POT...         3271.4      3284.4
# ITALIANS DO IT BETTER + AUTRE GAMME + RAGU DE V...         1543.7         0.0
# AUT MQ + SCE CLAS + CURRY INDIENNE TIKKA MASALA...         1092.1         0.0
# AUT MQ + LEGUMES + AIL + POT +  NON BIO                     877.2       692.4
# MQ FAB 1 PRX + SCE CLAS + PESTO CALABRESE + POT...          526.7      1241.3
# AUT MQ + SCE CLAS + HOMARD A LA CREME FRAICHE &...          498.0       654.4
# CASERTA + BOLO CLASSIQUE + BOLOGNAISE + POT +  ...          488.5       430.4
# AUT MQ + SCE CLAS + CURRY INDIENNE CURRY DOUX +...          388.5         0.0
# AUT MQ + SCE CLAS + SAUCE SUPREME A LA TRUFFE D...          217.4       214.9
# AUT MQ + SCE CLAS + BRUSCHETTA OLIVES NOIRES + ...          209.5        57.8
# AUT MQ + AUTRE GAMME + PIQUANTE CALABRESE + POT...          154.8       149.2
# VICTORIA + LEGUMES + NAPOLITAIN + POT +  NON BIO            128.8       721.6
# AUT MQ + SCE CLAS + CEPE + POT +  NON BIO                   100.0         0.0
# AUT MQ + LEGUMES + SPAGHETTI + POT +  NON BIO                82.5        56.5

# %%
#################################################################
# 4.3) EAN13_PROXI
# to be finalized

# %%
#for same_prod in df_M_SAME_PROD :
#     si marque != 'AUT MQ' et 'FAB 1 PRX' 'MMD' 'MDD 1 PRX'
#         list_prod_same_prod == df_M_PROD['N_SAME_PROD']== same_prod
#         list_proxy_potential= df_M_PROD[isinstance(O_EAN13) + isinstance(O_ingredient_n)]
#.        list_to_check=A - B
#.        temp_proxy=list_proxy_potential.max()
#.        for prod in list to check
#             df_M_PROD['EAN13_PROXY'][i] =  temp_proxy 
#.        df_M_SAME_PROD['SAME_PROD_EAN_PROXY'][same_prod]= temp_proxy

# %%
#creation of EAN13_PROXI
df_M_PROD['EAN13_PROXI'] = '0'

# %%
#Analysis of OPENFF_data for a specific N_SAME_PRODUCT to find best EAN13_PROXI

#'PANZANI, BOLO CLASSIQUE, BOLOGNAISE, POT, '
same_prod_to_analyse='ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE FER, '
temp = df_M_PROD[df_M_PROD['N_SAME_PRODUCT']==same_prod_to_analyse]
#filename=same_prod_to_analyse[:20] + '.csv'
#temp.to_csv('output_data/filename)

print(temp.shape)
temp[['N_EAN13','O_product_name', 'O_ingredients_n' ,'O_date_modified', 'N_SAME_PRODUCT', 'N_WEIGHT_num', 'N_DERNIER CAM', 'N_MARQUE', 'N_GAMME', 'N_RECETTES', 'N_ORGANIC', 'N_FORMAT', 'N_EMBALLAGE']]
# Out:
# (11, 57)
#            N_EAN13                                     O_product_name  \
# 211  3021690017298  La sauce italienne à la viande rôtie (3 x 3021...
# 212  3021690022971                        Sauce Italienne Max de Bœuf
# 213  3021690023701                                                NaN
# 214  3021690010176                                                NaN
# 215  3021690017694               La sauce italienne à la viande rôtie
# 216  3021690029536                                                NaN
# 217  3021690017267               La sauce italienne à la viande rôtie
# 218  3021690025200               Zapetti sauce italienne max de boeuf
# 219  3021690017571                                                NaN
# 220  3021690021059               La sauce italienne à la viande rôtie
# 221  3021690017281                  Sauce Italienne à La Viande Rôtie
#
#      O_ingredients_n O_interface_version_modified  \
# 211             15.0                20150316.jqm2
# 212             15.0                     20120622
# 213              NaN                          NaN
# 214              NaN                          NaN
# 215             15.0                     20120622
# 216              NaN                          NaN
# 217             15.0                20150316.jqm2
# 218             16.0                20150316.jqm2
# 219              NaN                          NaN
# 220             15.0                20150316.jqm2
# 221             17.0                20150316.jqm2
#
#                                         N_SAME_PRODUCT  N_WEIGHT_num  \
# 211  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...            95
# 212  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...           385
# 213  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...             0
# 214  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...             0
# 215  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...           190
# 216  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...             0
# 217  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...           190
# 218  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...           190
# 219  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...             0
# 220  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...             0
# 221  ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE ...           190
#
#      N_DERNIER CAM         N_MARQUE         N_GAMME N_RECETTES    N_ORGANIC  \
# 211       571285.2  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
# 212            0.8  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
# 213            0.0  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN  * not found
# 214         1869.5  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN  * not found
# 215           71.4  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
# 216        41804.6  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN  * not found
# 217       938411.1  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
# 218         7814.2  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
# 219           44.5  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN  * not found
# 220       169681.0  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN  * not found
# 221       687781.6  ZAPETTI BUITONI  BOLO CLASSIQUE    ITALIEN      NON BIO
#
#     N_FORMAT N_EMBALLAGE
# 211       FI     BTE FER
# 212       MF     BTE FER
# 213       MF     BTE FER
# 214       PF     BTE FER
# 215       PF     BTE FER
# 216       PF     BTE FER
# 217       PF     BTE FER
# 218       PF     BTE FER
# 219       PF     BTE FER
# 220       PF     BTE FER
# 221       PF     BTE FER

# %%
#################################################################
# 5) M_PROD with selected brands (italians_do_it_better perimeter)
#################################################################

# %%
#################################################################
# 6) M_PROD w
#################################################################

# %%
temp = df_M_PROD_SUM[df_M_PROD_SUM['N_DERNIER CAM'] > 500000]
print('Total sales 2019 : ', int(round(temp['N_DERNIER CAM'].sum())))
temp
# Out:
# Total sales 2019 :  36976704
#                                                     N_COUNT  O_COUNT  \
# N_SAME_PRODUCT
# PANZANI, LEGUMES, PROVENCALE, POT,                       17     10.0
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE, POT,                26     19.0
# PANZANI, LEGUMES, PT LEGUME, TUB,                         6      6.0
# PANZANI, LEGUMES, TOMATE CUI, POT,                       11     10.0
# ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE F...       11      7.0
# HEINZ, LEGUMES, AIL OIGNON, BRIC,                         8      3.0
# PANZANI, LEGUMES, TOMATES BASILIC, POT,                   9      4.0
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE PUR BOEUF, ...        8      6.0
# BARILLA, LEGUMES, BASILIC, POT,                           9      7.0
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE EXTRA RICHE...        3      3.0
# PANZANI, LEGUMES, TOM FRAICH, BTE FER,                    3      2.0
# BARILLA, PESTO, PESTO VERD, POT,                          4      3.0
# BARILLA, PESTO, PESTO RGE, POT,                           2      2.0
# BARILLA, BOLO CLASSIQUE, BOLOGNAISE, POT,                 7      4.0
# BARILLA, LEGUMES, PROVENCALE, POT,                        3      3.0
# BARILLA, LEGUMES, ARRABIATA, POT,                         6      4.0
# ZAPETTI BUITONI, LEGUMES, H OLIVE, BTE FER,               3      3.0
# PANZANI, PESTO, PESTO VERD, POT,                          3      2.0
# PANZANI, BOLO BALLS, NATURE, POT,                         3      2.0
# BARILLA, LEGUMES, TOMATE CUI, POT,                        2      2.0
# PANZANI, LEGUMES, OLIV BASIL, POT,                        5      4.0
# PANZANI, CREME, CARBONARA, POT,                           1      1.0
#
#                                                     N_DERNIER CAM  N_CAM AN-1  \
# N_SAME_PRODUCT
# PANZANI, LEGUMES, PROVENCALE, POT,                      4905419.6   4747571.5
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE, POT,               4899534.7   8800759.4
# PANZANI, LEGUMES, PT LEGUME, TUB,                       3071093.9   3081322.4
# PANZANI, LEGUMES, TOMATE CUI, POT,                      2670954.1   2632010.4
# ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE F...      2418763.9   2392954.5
# HEINZ, LEGUMES, AIL OIGNON, BRIC,                       2325710.4   2085754.5
# PANZANI, LEGUMES, TOMATES BASILIC, POT,                 2026021.2   1796281.9
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE PUR BOEUF, ...      1923095.6     79428.1
# BARILLA, LEGUMES, BASILIC, POT,                         1746062.2   1792045.8
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE EXTRA RICHE...      1203024.0   1155079.6
# PANZANI, LEGUMES, TOM FRAICH, BTE FER,                  1138381.1   1199943.5
# BARILLA, PESTO, PESTO VERD, POT,                        1065922.7    949657.4
# BARILLA, PESTO, PESTO RGE, POT,                         1004482.6    875035.7
# BARILLA, BOLO CLASSIQUE, BOLOGNAISE, POT,                956457.5    922002.8
# BARILLA, LEGUMES, PROVENCALE, POT,                       951896.6    861554.0
# BARILLA, LEGUMES, ARRABIATA, POT,                        878142.4    760727.1
# ZAPETTI BUITONI, LEGUMES, H OLIVE, BTE FER,              803789.5    795268.4
# PANZANI, PESTO, PESTO VERD, POT,                         693695.3    617756.7
# PANZANI, BOLO BALLS, NATURE, POT,                        670035.2    767792.1
# BARILLA, LEGUMES, TOMATE CUI, POT,                       581389.5    344266.2
# PANZANI, LEGUMES, OLIV BASIL, POT,                       541059.2    575318.7
# PANZANI, CREME, CARBONARA, POT,                          501772.9    458855.5
#
#                                                     MISSING_COUNT
# N_SAME_PRODUCT
# PANZANI, LEGUMES, PROVENCALE, POT,                              7
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE, POT,                       7
# PANZANI, LEGUMES, PT LEGUME, TUB,                               0
# PANZANI, LEGUMES, TOMATE CUI, POT,                              1
# ZAPETTI BUITONI, BOLO CLASSIQUE, ITALIEN, BTE F...              4
# HEINZ, LEGUMES, AIL OIGNON, BRIC,                               5
# PANZANI, LEGUMES, TOMATES BASILIC, POT,                         5
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE PUR BOEUF, ...              2
# BARILLA, LEGUMES, BASILIC, POT,                                 2
# PANZANI, BOLO CLASSIQUE, BOLOGNAISE EXTRA RICHE...              0
# PANZANI, LEGUMES, TOM FRAICH, BTE FER,                          1
# BARILLA, PESTO, PESTO VERD, POT,                                1
# BARILLA, PESTO, PESTO RGE, POT,                                 0
# BARILLA, BOLO CLASSIQUE, BOLOGNAISE, POT,                       3
# BARILLA, LEGUMES, PROVENCALE, POT,                              0
# BARILLA, LEGUMES, ARRABIATA, POT,                               2
# ZAPETTI BUITONI, LEGUMES, H OLIVE, BTE FER,                     0
# PANZANI, PESTO, PESTO VERD, POT,                                1
# PANZANI, BOLO BALLS, NATURE, POT,                               1
# BARILLA, LEGUMES, TOMATE CUI, POT,                              0
# PANZANI, LEGUMES, OLIV BASIL, POT,                              1
# PANZANI, CREME, CARBONARA, POT,                                 0

# %%
temp = df_M_PROD_SUM[df_M_PROD_SUM['N_DERNIER_CAM'] > 100000]

print('Number of products matched : ', df_M_PROD['N_DERNIER CAM'].count())
print('Sales of products matched : ', df_M_PROD['N_DERNIER CAM'].sum())

print('Number of products with sales > 100.000 euros : ', temp['N_DERNIER CAM'].count())
print('Sales of products > 100.000 euros : ', temp['N_DERNIER CAM'].sum())

print('Number of products with sales < 100.000 euros : ', temp['N_DERNIER CAM'].count() - df_M_PROD['N_DERNIER CAM'].count())
print('Sales of products < 100.000 euros : ', temp['N_DERNIER CAM'].sum() - df_M_PROD['N_DERNIER CAM'].sum())

temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-5db689c417cd> in <module>
# ----> 1 temp = df_M_PROD_SUM[df_M_PROD_SUM['N_DERNIER CAM'] > 100000]
#       2
#       3 print('Number of products matched : ', df_M_PROD['N_DERNIER CAM'].count())
#       4 print('Sales of products matched : ', df_M_PROD['N_DERNIER CAM'].sum())
#       5
#
# NameError: name 'df_M_PROD_SUM' is not defined

# %%
df_M_PROD_SUM['N_DERNIER CAM'].plot.hist(bins=50, title='sales per unique products', figsize=(12,5)).set(xlabel='sales', ylabel='number of unique products')
# Out:
# [Text(0, 0.5, 'number of unique products'), Text(0.5, 0, 'sales')]

# %%
temp.to_excel('sales_100000.xls')

# %%
df_prod_no_match = df_M_PROD_SUM[df_M_PROD_SUM['O_COUNT'] == 0]
df_prod_no_match
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59d5e02ac529> in <module>
# ----> 1 df_prod_no_match = df_M_PROD_SUM[df_M_PROD_SUM['O_COUNT'] == 0]
#       2 df_prod_no_match
#
# NameError: name 'df_M_PROD_SUM' is not defined

# %%
df_prod_no_match[['N_DERNIER CAM', 'N_COUNT']].sum()
# Out:
# N_DERNIER CAM    14780.1
# N_COUNT            101.0
# dtype: float64

# %%
(df_prod_no_match['N_DERNIER CAM'] != 0).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65c8a5dbd4a2> in <module>
# ----> 1 (df_prod_no_match['N_DERNIER CAM'] != 0).sum()
#
# NameError: name 'df_prod_no_match' is not defined
